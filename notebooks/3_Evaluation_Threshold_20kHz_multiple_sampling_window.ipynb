# %% [markdown]
# # Threshold Evaluation for multiple sampling values
#
# This stage evaluates the results with the detector, comparing them with the original spiketrains. To do this, it requires to load the NEO files for each value of resolution.

# %% [markdown]
# ## Loading NEO files

# %%
# %load_ext autoreload
# %autoreload 2

# %%
BASE_DIR="/mnt/Archivos/data"

# %%
from eapprocessor.tools.load import load_neo, load_count_evaluation, get_evaluation_files

# %%
noise_levels = [5, 25]
resolutions = [10,9,8,7,6,5,4,3]
fs=20000

# %%
neo_list=[]
neo_files=[]
for resolution in resolutions:
    neo_list_resolution = []
    neo_files_resolution =[]
    for noise_level in noise_levels:
        neo_dict, file = load_neo(f"{BASE_DIR}/output/preprocessor", verbose=True, resolution=resolution, 
                           noise_level=noise_level, fs=fs)
        neo_list_resolution += [neo_dict]
        neo_files_resolution += [file]
    
    neo_list += [neo_list_resolution]
    neo_files += [neo_files_resolution]
# Out:
# Search for pattern: *_10_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_10_5uV_20000Hz_2021-11-04_16-18.h5
# Search for pattern: *_10_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_10_25uV_20000Hz_2021-11-04_16-18.h5
# Search for pattern: *_9_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_9_5uV_20000Hz_2021-11-04_16-18.h5
# Search for pattern: *_9_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_9_25uV_20000Hz_2021-11-04_16-18.h5
# Search for pattern: *_8_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_8_5uV_20000Hz_2021-11-04_16-19.h5
# Search for pattern: *_8_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_8_25uV_20000Hz_2021-11-04_16-19.h5
# Search for pattern: *_7_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_7_5uV_20000Hz_2021-11-04_16-19.h5
# Search for pattern: *_7_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_7_25uV_20000Hz_2021-11-04_16-20.h5
# Search for pattern: *_6_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_6_5uV_20000Hz_2021-11-04_16-20.h5
# Search for pattern: *_6_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_6_25uV_20000Hz_2021-11-04_16-20.h5
# Search for pattern: *_5_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_5_5uV_20000Hz_2021-11-11_18-43.h5
# Search for pattern: *_5_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_5_25uV_20000Hz_2021-11-11_18-43.h5
# Search for pattern: *_4_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_4_5uV_20000Hz_2021-11-11_18-43.h5
# Search for pattern: *_4_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_4_25uV_20000Hz_2021-11-11_18-43.h5
# Search for pattern: *_3_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_3_5uV_20000Hz_2021-11-11_18-44.h5
# Search for pattern: *_3_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_3_25uV_20000Hz_2021-11-11_18-44.h5

# %% [markdown]
# ## Exploring converted signals

# %%
from eapprocessor.plot.signals import plot_transient_converted, plot_transient_recordings, plot_transient_neo

# %%
plot_transient_recordings(neo_list[0][0]["recordings"], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_converted(neo_list[0][0], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_converted(neo_list[4][0], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_neo(neo_list[0][0], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_neo(neo_list[4][0], channels=[27], t_stop=0.1,marker='.--')

# %% [markdown]
# ## Getting evaluation files

# %%
evaluator_files_dict_list = []
for neo_files_resolution in neo_files:
    evaluator_files_dict_list_resolution=[]
    for neo_file in neo_files_resolution: 
        file_dict = get_evaluation_files(f"{BASE_DIR}/output/evaluator",sourcefile=neo_file) 
        evaluator_files_dict_list_resolution += [file_dict]
    evaluator_files_dict_list += [evaluator_files_dict_list_resolution]
# Out:
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_10_5uV_20000Hz_2021-11-04_16-18.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_10_5uV_20000Hz_2021-11-04_16-27.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_10_5uV_20000Hz_2021-11-04_16-27.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_10_5uV_20000Hz_2021-11-04_16-27.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_10_25uV_20000Hz_2021-11-04_16-18.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_10_25uV_20000Hz_2021-11-04_16-28.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_10_25uV_20000Hz_2021-11-04_16-28.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_10_25uV_20000Hz_2021-11-04_16-28.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_9_5uV_20000Hz_2021-11-04_16-18.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_9_5uV_20000Hz_2021-11-04_16-30.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_9_5uV_20000Hz_2021-11-04_16-30.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_9_5uV_20000Hz_2021-11-04_16-30.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_9_25uV_20000Hz_2021-11-04_16-18.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_9_25uV_20000Hz_2021-11-04_16-31.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_9_25uV_20000Hz_2021-11-04_16-31.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_9_25uV_20000Hz_2021-11-04_16-31.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_8_5uV_20000Hz_2021-11-04_16-19.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_8_5uV_20000Hz_2021-11-04_16-32.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_8_5uV_20000Hz_2021-11-04_16-32.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_8_5uV_20000Hz_2021-11-04_16-32.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_8_25uV_20000Hz_2021-11-04_16-19.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_8_25uV_20000Hz_2021-11-04_16-33.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_8_25uV_20000Hz_2021-11-04_16-33.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_8_25uV_20000Hz_2021-11-04_16-33.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_7_5uV_20000Hz_2021-11-04_16-19.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_7_5uV_20000Hz_2021-11-04_16-35.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_7_5uV_20000Hz_2021-11-04_16-35.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_7_5uV_20000Hz_2021-11-04_16-35.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_7_25uV_20000Hz_2021-11-04_16-20.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_7_25uV_20000Hz_2021-11-04_16-36.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_7_25uV_20000Hz_2021-11-04_16-36.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_7_25uV_20000Hz_2021-11-04_16-36.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_6_5uV_20000Hz_2021-11-04_16-20.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_6_5uV_20000Hz_2021-11-04_16-37.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_6_5uV_20000Hz_2021-11-04_16-37.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_6_5uV_20000Hz_2021-11-04_16-37.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_6_25uV_20000Hz_2021-11-04_16-20.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_6_25uV_20000Hz_2021-11-04_16-38.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_6_25uV_20000Hz_2021-11-04_16-38.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_6_25uV_20000Hz_2021-11-04_16-38.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_5_5uV_20000Hz_2021-11-11_18-43.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_5_5uV_20000Hz_2021-11-12_00-04.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_5_5uV_20000Hz_2021-11-12_00-04.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_5_5uV_20000Hz_2021-11-12_00-04.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_5_25uV_20000Hz_2021-11-11_18-43.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_5_25uV_20000Hz_2021-11-12_00-05.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_5_25uV_20000Hz_2021-11-12_00-05.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_5_25uV_20000Hz_2021-11-12_00-05.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_4_5uV_20000Hz_2021-11-11_18-43.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_4_5uV_20000Hz_2021-11-12_00-05.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_4_5uV_20000Hz_2021-11-12_00-05.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_4_5uV_20000Hz_2021-11-12_00-05.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_4_25uV_20000Hz_2021-11-11_18-43.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_4_25uV_20000Hz_2021-11-12_00-06.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_4_25uV_20000Hz_2021-11-12_00-06.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_4_25uV_20000Hz_2021-11-12_00-06.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_3_5uV_20000Hz_2021-11-11_18-44.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_3_5uV_20000Hz_2021-11-12_00-06.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_3_5uV_20000Hz_2021-11-12_00-06.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_3_5uV_20000Hz_2021-11-12_00-06.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_3_25uV_20000Hz_2021-11-11_18-44.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_3_25uV_20000Hz_2021-11-12_00-07.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th_3_25uV_20000Hz_2021-11-12_00-07.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_neo_subset_50th_3_25uV_20000Hz_2021-11-12_00-07.h5')]

# %% [markdown]
# ## Getting indexes for spiketrains positions

# %%
spiketrain_obj_list = neo_list[0][0]["recordings"].spiketrains

# %%
import numpy as np

# %%
spiketrain_list = [np.array(spiketrain[:]) for spiketrain in spiketrain_obj_list]

# %%
timestamps = neo_list[0][0]["recordings"].timestamps[:]
print(timestamps)
# Out:
# [0.00000e+00 5.00000e-05 1.00000e-04 ... 9.99985e+00 9.99990e+00
#  9.99995e+00]

# %%
from eapprocessor.evaluator.spikes import estimate_sample_spikes, comparison_detection_spiketrain

# %%
indexes_list = []
errors_list = []
for spiketrain in spiketrain_list:
    indexes, errors = estimate_sample_spikes(spikes=spiketrain,timestamps=timestamps)
    indexes_list += [indexes]
    errors_list += [errors]

# %% [markdown]
# ## Evaluating for each noise level

# %%
from eapprocessor.process import get_results_evaluation_dataset_array
from eapprocessor.evaluator.spikes import convert_to_roc_list
from eapprocessor.plot.evaluator import plot_roc_list, plot_accuracy_list
from eapprocessor.tools.load import load_converted_values, load_neo, \
    load_count_evaluation, load_indexes, load_channels

# %%
def results_evaluator(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      noise_levels,
                      w,
                      window_time=None,
                      neo_files=None,
                      ):
    evaluator_files_neo = [evaluator_files_dict["neo_file"]
                           for evaluator_files_dict in evaluator_files_dict_list]
    neo_evaluation_dics = get_results_evaluation_dataset_array(evaluator_files_neo, 
                                                               indexes_list,
                                                               channel_idx=1,
                                                              window_time=window_time,
                                                              origin_files=neo_files)

    tpr_neo_list, fpr_neo_list = convert_to_roc_list(neo_evaluation_dics, 
                                                     range_reference=spike_indexes)

    print(tpr_neo_list.shape)
    
    for idx in range(len(tpr_neo_list)):
        plot_roc_list(fpr_list=fpr_neo_list[idx], tpr_list=tpr_neo_list[idx], 
                    labels=[f"w={w_i}" for w_i in w],
                    spiketrains_labels=spike_indexes,
                    append_title=f", Noise level {noise_levels[idx]}")

# %%
neo_files[0]
# Out:
# [PosixPath('/mnt/Archivos/data/output/preprocessor/preprocessed_neo_10_5uV_20000Hz_2021-11-04_16-18.h5'),
#  PosixPath('/mnt/Archivos/data/output/preprocessor/preprocessed_neo_10_25uV_20000Hz_2021-11-04_16-18.h5')]

# %%
neo_dict, _ = load_neo(filename=neo_files[0][0],
                                   is_lcadc=False)
neo_dict
# Out:
# {'adcinfo': {'resolution': 10, 'voltage_ref': 500},
#  'adc': <HDF5 dataset "adc": shape (32, 200000), type "<i8">,
#  'normalized': <HDF5 dataset "normalized": shape (32, 200000), type "<f8">,
#  'recordings': <MEArec.generators.recordinggenerator.RecordingGenerator at 0x7fa5ebd78310>,
#  'w': <HDF5 dataset "w": shape (4,), type "<i8">,
#  'neo': <HDF5 dataset "neo": shape (4, 32, 200000), type "<f8">}

# %%
neo_dict["recordings"].info["recordings"]["fs"]
# Out:
# 20000.0

# %%
results_evaluator(evaluator_files_dict_list[0],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32],
                 window_time=2.5e-3,
                 neo_files=neo_files[0])
# Out:
# (2, 4, 50, 3)

# %%
results_evaluator(evaluator_files_dict_list[1],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32],
                 window_time=2.5e-3,
                 neo_files=neo_files[1])
# Out:
# (2, 4, 50, 3)

# %%
results_evaluator(evaluator_files_dict_list[2],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32],
                 window_time=2.5e-3,
                 neo_files=neo_files[2])
# Out:
# (2, 4, 50, 3)

# %%
results_evaluator(evaluator_files_dict_list[3],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32],
                 window_time=2.5e-3,
                 neo_files=neo_files[3])
# Out:
# (2, 4, 50, 3)

# %%
results_evaluator(evaluator_files_dict_list[4],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32],
                 window_time=2.5e-3,
                 neo_files=neo_files[4])
# Out:
# (2, 4, 50, 3)

# %%
from eapprocessor.evaluator.spikes import comparison_detection_array_spiketrain_array, convert_to_roc, \
    convert_to_accuracy, convert_to_accuracy_list
from eapprocessor.tools.load import load_evaluation

# %%
def results_recordings(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      noise_levels):
    evaluator_files_rec = [load_evaluation(evaluator_files_dict["recordings_file"])
                           for evaluator_files_dict in evaluator_files_dict_list]
    
    comparison_recordings_list = [comparison_detection_array_spiketrain_array(indexes_list, dic["indexes"][1],50) 
                             for dic in evaluator_files_rec]

    tpr_rec_list = []
    fpr_rec_list = []
    for comparison_rec in comparison_recordings_list:
        tpr_rec, fpr_rec = convert_to_roc(comparison_rec, range_reference=spike_indexes)
        tpr_rec_list +=[tpr_rec]
        fpr_rec_list +=[fpr_rec]
    
    plot_roc_list(fpr_list=fpr_rec_list, tpr_list=tpr_rec_list, 
                labels=[f"noise={noise_level}" for noise_level in noise_levels],
                spiketrains_labels=spike_indexes)

# %%
results_recordings(evaluator_files_dict_list[0],
                 indexes_list,
                 [5,7,8],
                 noise_levels)

# %%
def results_converted(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      noise_levels):
    evaluator_files_rec = [load_evaluation(evaluator_files_dict["normalized_file"])
                           for evaluator_files_dict in evaluator_files_dict_list]
    
    comparison_recordings_list = [comparison_detection_array_spiketrain_array(indexes_list, dic["indexes"][1],50) 
                             for dic in evaluator_files_rec]

    tpr_rec_list = []
    fpr_rec_list = []
    for comparison_rec in comparison_recordings_list:
        tpr_rec, fpr_rec = convert_to_roc(comparison_rec, range_reference=spike_indexes)
        tpr_rec_list +=[tpr_rec]
        fpr_rec_list +=[fpr_rec]
    
    plot_roc_list(fpr_list=fpr_rec_list, tpr_list=tpr_rec_list, 
                labels=[f"noise={noise_level}" for noise_level in noise_levels],
                spiketrains_labels=spike_indexes)

# %%
results_converted(evaluator_files_dict_list[4],
                 indexes_list,
                 [5,7,8],
                 noise_levels)

# %%
def results_acuracy_converted(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      labels):
    evaluator_files_rec = [load_evaluation(evaluator_files_dict["normalized_file"])
                           for evaluator_files_dict in evaluator_files_dict_list]
    
    comparison_recordings_list = [comparison_detection_array_spiketrain_array(indexes_list, dic["indexes"][1],50) 
                             for dic in evaluator_files_rec]

    accuracy_list = convert_to_accuracy_list(comparison_recordings_list, range_reference=spike_indexes)

    
    plot_accuracy_list(accuracy_list=accuracy_list, 
                labels=labels,
                spiketrains_labels=spike_indexes)
    
    return accuracy_list

# %%
results_acuracy_converted(evaluator_files_dict_list[0],
                 indexes_list,
                 [5,7,8],
                 [f"noise={noise_level}" for noise_level in noise_levels])
# Out:
# array([[[0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01456554, 0.02730461, 0.03510532],
#         [0.01647727, 0.03112507, 0.03989741],
#         [0.02617329, 0.04959054, 0.06292135],
#         [0.05101143, 0.09637489, 0.12048193],
#         [0.07379135, 0.13832487, 0.17456359],
#         [0.09105181, 0.17219589, 0.22292994],
#         [0.10800745, 0.2       , 0.2745098 ],
#         [0.11530815, 0.21456693, 0.30634573],
#         [0.12314225, 0.22755741, 0.3271028 ],
#         [0.1277533 , 0.23747277, 0.3406326 ],
#         [0.13063063, 0.24222222, 0.34482759],
#         [0.13647059, 0.24654378, 0.35353535],
#         [0.13701923, 0.25178147, 0.35989717],
#         [0.14213198, 0.25879397, 0.37634409],
#         [0.13934426, 0.24064171, 0.40524781],
#         [0.13707165, 0.2111437 , 0.46644295],
#         [0.10600707, 0.17320261, 0.56504065],
#         [0.07053942, 0.09677419, 0.71649485],
#         [0.04072398, 0.0651341 , 0.83233533],
#         [0.01877934, 0.04743083, 0.89677419],
#         [0.01463415, 0.03252033, 0.95205479],
#         [0.015     , 0.0204918 , 0.97183099],
#         [0.01515152, 0.01646091, 0.97163121],
#         [0.01530612, 0.01659751, 0.95744681],
#         [0.01538462, 0.01244813, 0.96428571],
#         [0.01578947, 0.01271186, 0.92857143],
#         [0.01704545, 0.01339286, 0.84285714],
#         [0.01863354, 0.01428571, 0.74285714],
#         [0.02083333, 0.01025641, 0.62857143],
#         [0.0234375 , 0.01117318, 0.51428571],
#         [0.02702703, 0.01234568, 0.39285714],
#         [0.03191489, 0.00684932, 0.27142857],
#         [0.03703704, 0.0075188 , 0.17857143],
#         [0.02631579, 0.00787402, 0.13571429],
#         [0.02898551, 0.00833333, 0.08571429],
#         [0.03125   , 0.00869565, 0.05      ],
#         [0.03278689, 0.00892857, 0.02857143],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.03389831, 0.00900901, 0.02142857],
#         [0.01694915, 0.00909091, 0.01428571],
#         [0.01694915, 0.00909091, 0.01428571],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286]],
#
#        [[0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01452178, 0.02726363, 0.0350438 ],
#         [0.01453634, 0.02727045, 0.0350438 ],
#         [0.01458019, 0.02736631, 0.03511412],
#         [0.01472829, 0.02756005, 0.03540718],
#         [0.01506885, 0.02822372, 0.03616637],
#         [0.01570964, 0.02895022, 0.03784807],
#         [0.01686047, 0.03017992, 0.04097161],
#         [0.01897906, 0.03352865, 0.04573669],
#         [0.0212766 , 0.03567528, 0.05126327],
#         [0.02526132, 0.03955288, 0.06079027],
#         [0.02919321, 0.04206099, 0.07377919],
#         [0.03561828, 0.05039788, 0.09256757],
#         [0.03801653, 0.05935697, 0.11450382],
#         [0.04431017, 0.06393606, 0.13836478],
#         [0.04986877, 0.06896552, 0.17744154],
#         [0.04958678, 0.06793049, 0.21640489],
#         [0.05579399, 0.07185629, 0.26636569],
#         [0.06149733, 0.07729469, 0.31284916],
#         [0.06624606, 0.06336088, 0.35409836],
#         [0.06153846, 0.06188925, 0.38823529],
#         [0.06635071, 0.0530303 , 0.42523364],
#         [0.05084746, 0.05309735, 0.43783784],
#         [0.05660377, 0.05288462, 0.41714286],
#         [0.05405405, 0.05076142, 0.38823529],
#         [0.03787879, 0.04444444, 0.33128834],
#         [0.02586207, 0.04938272, 0.2987013 ],
#         [0.02777778, 0.03870968, 0.27152318],
#         [0.0326087 , 0.02836879, 0.2137931 ],
#         [0.02298851, 0.02205882, 0.18881119],
#         [0.02597403, 0.02380952, 0.11888112],
#         [0.02777778, 0.02479339, 0.0915493 ],
#         [0.02816901, 0.025     , 0.08450704],
#         [0.02985075, 0.00847458, 0.07142857],
#         [0.03076923, 0.00854701, 0.06428571],
#         [0.03174603, 0.00869565, 0.05      ],
#         [0.03278689, 0.        , 0.03571429],
#         [0.03448276, 0.        , 0.01428571],
#         [0.03448276, 0.        , 0.01428571]]])

# %%
results_acuracy_converted(evaluator_files_dict_list[4],
                 indexes_list,
                 [5,7,8],
                 [f"noise={noise_level}" for noise_level in noise_levels])
# Out:
# array([[[0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01847134, 0.03486884, 0.04458599],
#         [0.01847134, 0.03486884, 0.04458599],
#         [0.01847134, 0.03486884, 0.04458599],
#         [0.01847134, 0.03486884, 0.04458599],
#         [0.10357143, 0.19360568, 0.2739726 ],
#         [0.10357143, 0.19360568, 0.2739726 ],
#         [0.10357143, 0.19360568, 0.2739726 ],
#         [0.13333333, 0.24716553, 0.33980583],
#         [0.13333333, 0.24716553, 0.33980583],
#         [0.13333333, 0.24716553, 0.33980583],
#         [0.13333333, 0.24716553, 0.33980583],
#         [0.15447154, 0.28648649, 0.38781163],
#         [0.15447154, 0.28648649, 0.38781163],
#         [0.15447154, 0.28648649, 0.38781163],
#         [0.12891986, 0.21967213, 0.53875969],
#         [0.12891986, 0.21967213, 0.53875969],
#         [0.12891986, 0.21967213, 0.53875969],
#         [0.12891986, 0.21967213, 0.53875969],
#         [0.01904762, 0.048     , 0.91447368],
#         [0.01904762, 0.048     , 0.91447368],
#         [0.01904762, 0.048     , 0.91447368],
#         [0.01538462, 0.01659751, 0.95744681],
#         [0.01538462, 0.01659751, 0.95744681],
#         [0.01538462, 0.01659751, 0.95744681],
#         [0.01538462, 0.01659751, 0.95744681],
#         [0.01744186, 0.01351351, 0.82857143],
#         [0.01744186, 0.01351351, 0.82857143],
#         [0.01744186, 0.01351351, 0.82857143],
#         [0.01744186, 0.01351351, 0.82857143],
#         [0.02777778, 0.01257862, 0.37142857],
#         [0.02777778, 0.01257862, 0.37142857],
#         [0.02777778, 0.01257862, 0.37142857],
#         [0.02898551, 0.00833333, 0.08571429],
#         [0.02898551, 0.00833333, 0.08571429],
#         [0.02898551, 0.00833333, 0.08571429],
#         [0.02898551, 0.00833333, 0.08571429],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.01694915, 0.00909091, 0.01428571],
#         [0.01694915, 0.00909091, 0.01428571],
#         [0.01694915, 0.00909091, 0.01428571],
#         [0.01694915, 0.00909091, 0.01428571],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286]],
#
#        [[0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01465757, 0.02753916, 0.03535354],
#         [0.01465757, 0.02753916, 0.03535354],
#         [0.01465757, 0.02753916, 0.03535354],
#         [0.01698389, 0.03128655, 0.04092371],
#         [0.01698389, 0.03128655, 0.04092371],
#         [0.01698389, 0.03128655, 0.04092371],
#         [0.01698389, 0.03128655, 0.04092371],
#         [0.02672811, 0.04262145, 0.06430868],
#         [0.02672811, 0.04262145, 0.06430868],
#         [0.02672811, 0.04262145, 0.06430868],
#         [0.04684512, 0.06672932, 0.1292517 ],
#         [0.04684512, 0.06672932, 0.1292517 ],
#         [0.04684512, 0.06672932, 0.1292517 ],
#         [0.05578512, 0.07930368, 0.26855895],
#         [0.05578512, 0.07930368, 0.26855895],
#         [0.05578512, 0.07930368, 0.26855895],
#         [0.05578512, 0.07930368, 0.26855895],
#         [0.06976744, 0.05863192, 0.40079365],
#         [0.06976744, 0.05863192, 0.40079365],
#         [0.06976744, 0.05863192, 0.40079365],
#         [0.05769231, 0.05339806, 0.43859649],
#         [0.05769231, 0.05339806, 0.43859649],
#         [0.05769231, 0.05339806, 0.43859649],
#         [0.02564103, 0.04938272, 0.32236842],
#         [0.02564103, 0.04938272, 0.32236842],
#         [0.02564103, 0.04938272, 0.32236842],
#         [0.02564103, 0.04938272, 0.32236842],
#         [0.02409639, 0.02272727, 0.16901408],
#         [0.02409639, 0.02272727, 0.16901408],
#         [0.02409639, 0.02272727, 0.16901408],
#         [0.02816901, 0.025     , 0.08450704],
#         [0.02816901, 0.025     , 0.08450704],
#         [0.02816901, 0.025     , 0.08450704],
#         [0.03225806, 0.        , 0.04285714],
#         [0.03225806, 0.        , 0.04285714],
#         [0.03225806, 0.        , 0.04285714]]])

# %%
evaluator_files_5uv_list= [evaluator_files[0] for evaluator_files in  evaluator_files_dict_list]
evaluator_files_25uv_list= [evaluator_files[1] for evaluator_files in  evaluator_files_dict_list]

# %%
results_5uv=results_acuracy_converted(evaluator_files_5uv_list,
                 indexes_list,
                 [5,7,8],
                 [f"resolution={resolution}" for resolution in resolutions])

# %%
results_25uv=results_acuracy_converted(evaluator_files_25uv_list,
                 indexes_list,
                 [5,7,8],
                 [f"resolution={resolution}" for resolution in resolutions])

# %%
results_5uv_t = np.transpose(results_5uv, (2, 0, 1))
results_5uv_t.shape
# Out:
# (3, 8, 50)

# %%
results_25uv_t = np.transpose(results_25uv, (2, 0, 1))
results_25uv_t.shape
# Out:
# (3, 8, 50)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
for idx,spiketrain in enumerate([5,7,8]):
    vector = results_5uv_t[idx].max(axis=1)
    ax.plot(resolutions,vector,label=f"Spiketrain {spiketrain}")
    ax.set_xlabel("Resolutions")
    ax.set_ylabel("Accuracy")
    ax.legend(loc="best")
    ax.set_title("Variation with resolution, 5uV noise")
    ax.grid(True)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
for idx,spiketrain in enumerate([5,7,8]):
    vector = results_25uv_t[idx].max(axis=1)
    plt.plot(resolutions,vector,label=f"Spiketrain {spiketrain}")
    ax.set_xlabel("Resolutions")
    ax.set_ylabel("Accuracy")
    ax.legend(loc="best")
    ax.set_title("Variation with resolution, 25uV noise")
    ax.grid(True)
