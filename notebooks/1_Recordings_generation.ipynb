# %% [markdown]
# # Recordings generation
#
# This process requires a set of steps which are:
#
# 1. Templates generation
# 2. Recordings generation

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LuighiV/eapprocessor/blob/master/notebooks/1_Recordings_generation.ipynb)

# %% [markdown]
# ## Templates generation

# %% [markdown]
# This generation uses a set of cell models which are the provided by the MEArec package:
# https://github.com/alejoe91/MEArec/tree/master/MEArec/cell_models/bbp

# %%
# %load_ext autoreload
# %autoreload 2

# %%
config = {
    "config_folder": "../data/mearec",
    "recordings_folder": "/mnt/Archivos/data/output/recordings",
    "templates_folder": "/mnt/Archivos/data/output/templates"
}

# %%
from eapprocessor.mearec.api import generate_templates, generate_recordings, load_recordings

# %%
tempgen = generate_templates(config_folder=config["config_folder"],
                            templates_folder=config["templates_folder"],
                            verbose=True, recompile=True)
# Out:
# /mnt/Archivos/data/output/templates
# /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp
# Compiling NEURON models
# /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods
# Mod files: "./CaDynamics_E2.mod" "./Ca_HVA.mod" "./Ca_LVAst.mod" "./Ca.mod" "./Ih.mod" "./Im.mod" "./K_Pst.mod" "./K_Tst.mod" "./Nap_Et2.mod" "./NaTa_t.mod" "./NaTs2_t.mod" "./ProbAMPANMDA_EMS.mod" "./ProbGABAAB_EMS.mod" "./SK_E2.mod" "./SKv3_1.mod"
#
# COBJS=''
#  -> Compiling mod_func.c
# gcc -O2   -I.   -I/home/luighi/.local/lib/python3.9/site-packages/neuron/.data/include  -I/nrnwheel/openmpi/include -fPIC -c mod_func.c -o mod_func.o
#  => LINKING shared library ./libnrnmech.so
# g++ -O2 -DVERSION_INFO='8.0.0' -std=c++11 -shared -fPIC  -I /home/luighi/.local/lib/python3.9/site-packages/neuron/.data/include -o ./libnrnmech.so -Wl,-soname,libnrnmech.so \
#   ./mod_func.o ./CaDynamics_E2.o ./Ca_HVA.o ./Ca_LVAst.o ./Ca.o ./Ih.o ./Im.o ./K_Pst.o ./K_Tst.o ./Nap_Et2.o ./NaTa_t.o ./NaTs2_t.o ./ProbAMPANMDA_EMS.o ./ProbGABAAB_EMS.o ./SK_E2.o ./SKv3_1.o  -L/home/luighi/.local/lib/python3.9/site-packages/neuron/.data/lib -lnrniv -Wl,-rpath,/home/luighi/.local/lib/python3.9/site-packages/neuron/.data/lib
# rm -f ./.libs/libnrnmech.so ; mkdir -p ./.libs ; cp ./libnrnmech.so ./.libs/libnrnmech.so
# Successfully created x86_64/special
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_BP_bAC217_1 1/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_BP_bAC217_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_BP_bAC217_1
# numprocs=1
# /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods/x86_64/.libs/libnrnmech.so
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# 	1
# 	1
# 	1
# template bAC217_L5_BP_d0cc8d7615 exist already
# Cell L5_BP_bAC217_1 extracellular spikes to be simulated
# Cell: L5_BP_bAC217_1 Progress: [1/50]
# Cell: L5_BP_bAC217_1 Progress: [2/50]
# Cell: L5_BP_bAC217_1 Progress: [3/50]
# Cell: L5_BP_bAC217_1 Progress: [4/50]
# Cell: L5_BP_bAC217_1 Progress: [5/50]
# Cell: L5_BP_bAC217_1 Progress: [6/50]
# Cell: L5_BP_bAC217_1 Progress: [7/50]
# Cell: L5_BP_bAC217_1 Progress: [8/50]
# Cell: L5_BP_bAC217_1 Progress: [9/50]
# Timeout finding spikes above noise level forL5_BP_bAC217_1, more than 120
# Done generating EAPs for L5_BP_bAC217_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_BTC_bAC217_1 2/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_BTC_bAC217_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_BTC_bAC217_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# 	1
# 	1
# 	1
# template bAC217_L5_BTC_160272643a exist already
# NEURON: bAC217_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate bAC217_biophys
#                             ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file(1, "biophysics.hoc")
# Cell L5_BTC_bAC217_1 extracellular spikes to be simulated
# Cell: L5_BTC_bAC217_1 Progress: [1/50]
# Cell: L5_BTC_bAC217_1 Progress: [2/50]
# Cell: L5_BTC_bAC217_1 Progress: [3/50]
# Cell: L5_BTC_bAC217_1 Progress: [4/50]
# Cell: L5_BTC_bAC217_1 Progress: [5/50]
# Cell: L5_BTC_bAC217_1 Progress: [6/50]
# Cell: L5_BTC_bAC217_1 Progress: [7/50]
# Cell: L5_BTC_bAC217_1 Progress: [8/50]
# Cell: L5_BTC_bAC217_1 Progress: [9/50]
# Cell: L5_BTC_bAC217_1 Progress: [10/50]
# Cell: L5_BTC_bAC217_1 Progress: [11/50]
# Cell: L5_BTC_bAC217_1 Progress: [12/50]
# Cell: L5_BTC_bAC217_1 Progress: [13/50]
# Cell: L5_BTC_bAC217_1 Progress: [14/50]
# Cell: L5_BTC_bAC217_1 Progress: [15/50]
# Cell: L5_BTC_bAC217_1 Progress: [16/50]
# Cell: L5_BTC_bAC217_1 Progress: [17/50]
# Cell: L5_BTC_bAC217_1 Progress: [18/50]
# Cell: L5_BTC_bAC217_1 Progress: [19/50]
# Cell: L5_BTC_bAC217_1 Progress: [20/50]
# Cell: L5_BTC_bAC217_1 Progress: [21/50]
# Cell: L5_BTC_bAC217_1 Progress: [22/50]
# Cell: L5_BTC_bAC217_1 Progress: [23/50]
# Cell: L5_BTC_bAC217_1 Progress: [24/50]
# Cell: L5_BTC_bAC217_1 Progress: [25/50]
# Cell: L5_BTC_bAC217_1 Progress: [26/50]
# Cell: L5_BTC_bAC217_1 Progress: [27/50]
# Cell: L5_BTC_bAC217_1 Progress: [28/50]
# Cell: L5_BTC_bAC217_1 Progress: [29/50]
# Cell: L5_BTC_bAC217_1 Progress: [30/50]
# Cell: L5_BTC_bAC217_1 Progress: [31/50]
# Cell: L5_BTC_bAC217_1 Progress: [32/50]
# Cell: L5_BTC_bAC217_1 Progress: [33/50]
# Cell: L5_BTC_bAC217_1 Progress: [34/50]
# Cell: L5_BTC_bAC217_1 Progress: [35/50]
# Cell: L5_BTC_bAC217_1 Progress: [36/50]
# Cell: L5_BTC_bAC217_1 Progress: [37/50]
# Cell: L5_BTC_bAC217_1 Progress: [38/50]
# Cell: L5_BTC_bAC217_1 Progress: [39/50]
# Cell: L5_BTC_bAC217_1 Progress: [40/50]
# Cell: L5_BTC_bAC217_1 Progress: [41/50]
# Cell: L5_BTC_bAC217_1 Progress: [42/50]
# Cell: L5_BTC_bAC217_1 Progress: [43/50]
# Cell: L5_BTC_bAC217_1 Progress: [44/50]
# Cell: L5_BTC_bAC217_1 Progress: [45/50]
# Cell: L5_BTC_bAC217_1 Progress: [46/50]
# Cell: L5_BTC_bAC217_1 Progress: [47/50]
# Cell: L5_BTC_bAC217_1 Progress: [48/50]
# Cell: L5_BTC_bAC217_1 Progress: [49/50]
# Cell: L5_BTC_bAC217_1 Progress: [50/50]
# Done generating EAPs for L5_BTC_bAC217_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_ChC_cACint209_1 3/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_ChC_cACint209_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_ChC_cACint209_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# 	1
# 	1
# 	1
# template cACint209_L5_ChC_e98f63217d exist already
# Cell L5_ChC_cACint209_1 extracellular spikes to be simulated
# Cell: L5_ChC_cACint209_1 Progress: [1/50]
# Cell: L5_ChC_cACint209_1 Progress: [2/50]
# Cell: L5_ChC_cACint209_1 Progress: [3/50]
# Cell: L5_ChC_cACint209_1 Progress: [4/50]
# Cell: L5_ChC_cACint209_1 Progress: [5/50]
# Cell: L5_ChC_cACint209_1 Progress: [6/50]
# Cell: L5_ChC_cACint209_1 Progress: [7/50]
# Cell: L5_ChC_cACint209_1 Progress: [8/50]
# Cell: L5_ChC_cACint209_1 Progress: [9/50]
# Cell: L5_ChC_cACint209_1 Progress: [10/50]
# Cell: L5_ChC_cACint209_1 Progress: [11/50]
# Cell: L5_ChC_cACint209_1 Progress: [12/50]
# Cell: L5_ChC_cACint209_1 Progress: [13/50]
# Cell: L5_ChC_cACint209_1 Progress: [14/50]
# Cell: L5_ChC_cACint209_1 Progress: [15/50]
# Cell: L5_ChC_cACint209_1 Progress: [16/50]
# Cell: L5_ChC_cACint209_1 Progress: [17/50]
# Cell: L5_ChC_cACint209_1 Progress: [18/50]
# Cell: L5_ChC_cACint209_1 Progress: [19/50]
# Cell: L5_ChC_cACint209_1 Progress: [20/50]
# Cell: L5_ChC_cACint209_1 Progress: [21/50]
# Cell: L5_ChC_cACint209_1 Progress: [22/50]
# Cell: L5_ChC_cACint209_1 Progress: [23/50]
# Cell: L5_ChC_cACint209_1 Progress: [24/50]
# Cell: L5_ChC_cACint209_1 Progress: [25/50]
# Cell: L5_ChC_cACint209_1 Progress: [26/50]
# Cell: L5_ChC_cACint209_1 Progress: [27/50]
# Cell: L5_ChC_cACint209_1 Progress: [28/50]
# Cell: L5_ChC_cACint209_1 Progress: [29/50]
# Cell: L5_ChC_cACint209_1 Progress: [30/50]
# Cell: L5_ChC_cACint209_1 Progress: [31/50]
# Cell: L5_ChC_cACint209_1 Progress: [32/50]
# Cell: L5_ChC_cACint209_1 Progress: [33/50]
# Cell: L5_ChC_cACint209_1 Progress: [34/50]
# Cell: L5_ChC_cACint209_1 Progress: [35/50]
# Cell: L5_ChC_cACint209_1 Progress: [36/50]
# Cell: L5_ChC_cACint209_1 Progress: [37/50]
# Cell: L5_ChC_cACint209_1 Progress: [38/50]
# Cell: L5_ChC_cACint209_1 Progress: [39/50]
# Cell: L5_ChC_cACint209_1 Progress: [40/50]
# Cell: L5_ChC_cACint209_1 Progress: [41/50]
# Cell: L5_ChC_cACint209_1 Progress: [42/50]
# Cell: L5_ChC_cACint209_1 Progress: [43/50]
# Cell: L5_ChC_cACint209_1 Progress: [44/50]
# Cell: L5_ChC_cACint209_1 Progress: [45/50]
# Cell: L5_ChC_cACint209_1 Progress: [46/50]
# Cell: L5_ChC_cACint209_1 Progress: [47/50]
# Cell: L5_ChC_cACint209_1 Progress: [48/50]
# Cell: L5_ChC_cACint209_1 Progress: [49/50]
# Cell: L5_ChC_cACint209_1 Progress: [50/50]
# Done generating EAPs for L5_ChC_cACint209_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_DBC_bAC217_1 4/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_DBC_bAC217_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_DBC_bAC217_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# NEURON: bAC217_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate bAC217_biophys
#                             ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file(1, "biophysics.hoc")
# 	1
# 	1
# 	1
# template bAC217_L5_DBC_4765d943f4 exist already
# Cell L5_DBC_bAC217_1 extracellular spikes to be simulated
# Cell: L5_DBC_bAC217_1 Progress: [1/50]
# Cell: L5_DBC_bAC217_1 Progress: [2/50]
# Cell: L5_DBC_bAC217_1 Progress: [3/50]
# Cell: L5_DBC_bAC217_1 Progress: [4/50]
# Cell: L5_DBC_bAC217_1 Progress: [5/50]
# Cell: L5_DBC_bAC217_1 Progress: [6/50]
# Cell: L5_DBC_bAC217_1 Progress: [7/50]
# Cell: L5_DBC_bAC217_1 Progress: [8/50]
# Cell: L5_DBC_bAC217_1 Progress: [9/50]
# Cell: L5_DBC_bAC217_1 Progress: [10/50]
# Cell: L5_DBC_bAC217_1 Progress: [11/50]
# Cell: L5_DBC_bAC217_1 Progress: [12/50]
# Cell: L5_DBC_bAC217_1 Progress: [13/50]
# Cell: L5_DBC_bAC217_1 Progress: [14/50]
# Cell: L5_DBC_bAC217_1 Progress: [15/50]
# Cell: L5_DBC_bAC217_1 Progress: [16/50]
# Cell: L5_DBC_bAC217_1 Progress: [17/50]
# Cell: L5_DBC_bAC217_1 Progress: [18/50]
# Cell: L5_DBC_bAC217_1 Progress: [19/50]
# Cell: L5_DBC_bAC217_1 Progress: [20/50]
# Cell: L5_DBC_bAC217_1 Progress: [21/50]
# Cell: L5_DBC_bAC217_1 Progress: [22/50]
# Cell: L5_DBC_bAC217_1 Progress: [23/50]
# Cell: L5_DBC_bAC217_1 Progress: [24/50]
# Cell: L5_DBC_bAC217_1 Progress: [25/50]
# Cell: L5_DBC_bAC217_1 Progress: [26/50]
# Cell: L5_DBC_bAC217_1 Progress: [27/50]
# Cell: L5_DBC_bAC217_1 Progress: [28/50]
# Cell: L5_DBC_bAC217_1 Progress: [29/50]
# Cell: L5_DBC_bAC217_1 Progress: [30/50]
# Cell: L5_DBC_bAC217_1 Progress: [31/50]
# Cell: L5_DBC_bAC217_1 Progress: [32/50]
# Cell: L5_DBC_bAC217_1 Progress: [33/50]
# Cell: L5_DBC_bAC217_1 Progress: [34/50]
# Cell: L5_DBC_bAC217_1 Progress: [35/50]
# Cell: L5_DBC_bAC217_1 Progress: [36/50]
# Cell: L5_DBC_bAC217_1 Progress: [37/50]
# Cell: L5_DBC_bAC217_1 Progress: [38/50]
# Cell: L5_DBC_bAC217_1 Progress: [39/50]
# Cell: L5_DBC_bAC217_1 Progress: [40/50]
# Cell: L5_DBC_bAC217_1 Progress: [41/50]
# Cell: L5_DBC_bAC217_1 Progress: [42/50]
# Cell: L5_DBC_bAC217_1 Progress: [43/50]
# Cell: L5_DBC_bAC217_1 Progress: [44/50]
# Cell: L5_DBC_bAC217_1 Progress: [45/50]
# Cell: L5_DBC_bAC217_1 Progress: [46/50]
# Cell: L5_DBC_bAC217_1 Progress: [47/50]
# Cell: L5_DBC_bAC217_1 Progress: [48/50]
# Cell: L5_DBC_bAC217_1 Progress: [49/50]
# Cell: L5_DBC_bAC217_1 Progress: [50/50]
# Done generating EAPs for L5_DBC_bAC217_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_LBC_bAC217_1 5/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_LBC_bAC217_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_LBC_bAC217_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# NEURON: bAC217_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate bAC217_biophys
#                             ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file(1, "biophysics.hoc")
# 	1
# 	1
# 	1
# template bAC217_L5_LBC_c2cff91741 exist already
# Cell L5_LBC_bAC217_1 extracellular spikes to be simulated
# Cell: L5_LBC_bAC217_1 Progress: [1/50]
# Cell: L5_LBC_bAC217_1 Progress: [2/50]
# Cell: L5_LBC_bAC217_1 Progress: [3/50]
# Cell: L5_LBC_bAC217_1 Progress: [4/50]
# Cell: L5_LBC_bAC217_1 Progress: [5/50]
# Cell: L5_LBC_bAC217_1 Progress: [6/50]
# Cell: L5_LBC_bAC217_1 Progress: [7/50]
# Cell: L5_LBC_bAC217_1 Progress: [8/50]
# Cell: L5_LBC_bAC217_1 Progress: [9/50]
# Cell: L5_LBC_bAC217_1 Progress: [10/50]
# Cell: L5_LBC_bAC217_1 Progress: [11/50]
# Cell: L5_LBC_bAC217_1 Progress: [12/50]
# Cell: L5_LBC_bAC217_1 Progress: [13/50]
# Cell: L5_LBC_bAC217_1 Progress: [14/50]
# Cell: L5_LBC_bAC217_1 Progress: [15/50]
# Cell: L5_LBC_bAC217_1 Progress: [16/50]
# Cell: L5_LBC_bAC217_1 Progress: [17/50]
# Cell: L5_LBC_bAC217_1 Progress: [18/50]
# Cell: L5_LBC_bAC217_1 Progress: [19/50]
# Cell: L5_LBC_bAC217_1 Progress: [20/50]
# Cell: L5_LBC_bAC217_1 Progress: [21/50]
# Cell: L5_LBC_bAC217_1 Progress: [22/50]
# Cell: L5_LBC_bAC217_1 Progress: [23/50]
# Cell: L5_LBC_bAC217_1 Progress: [24/50]
# Cell: L5_LBC_bAC217_1 Progress: [25/50]
# Cell: L5_LBC_bAC217_1 Progress: [26/50]
# Cell: L5_LBC_bAC217_1 Progress: [27/50]
# Cell: L5_LBC_bAC217_1 Progress: [28/50]
# Cell: L5_LBC_bAC217_1 Progress: [29/50]
# Cell: L5_LBC_bAC217_1 Progress: [30/50]
# Cell: L5_LBC_bAC217_1 Progress: [31/50]
# Cell: L5_LBC_bAC217_1 Progress: [32/50]
# Cell: L5_LBC_bAC217_1 Progress: [33/50]
# Cell: L5_LBC_bAC217_1 Progress: [34/50]
# Cell: L5_LBC_bAC217_1 Progress: [35/50]
# Cell: L5_LBC_bAC217_1 Progress: [36/50]
# Cell: L5_LBC_bAC217_1 Progress: [37/50]
# Cell: L5_LBC_bAC217_1 Progress: [38/50]
# Cell: L5_LBC_bAC217_1 Progress: [39/50]
# Cell: L5_LBC_bAC217_1 Progress: [40/50]
# Cell: L5_LBC_bAC217_1 Progress: [41/50]
# Cell: L5_LBC_bAC217_1 Progress: [42/50]
# Cell: L5_LBC_bAC217_1 Progress: [43/50]
# Cell: L5_LBC_bAC217_1 Progress: [44/50]
# Cell: L5_LBC_bAC217_1 Progress: [45/50]
# Cell: L5_LBC_bAC217_1 Progress: [46/50]
# Cell: L5_LBC_bAC217_1 Progress: [47/50]
# Cell: L5_LBC_bAC217_1 Progress: [48/50]
# Cell: L5_LBC_bAC217_1 Progress: [49/50]
# Cell: L5_LBC_bAC217_1 Progress: [50/50]
# Done generating EAPs for L5_LBC_bAC217_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_MC_bAC217_1 6/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_MC_bAC217_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_MC_bAC217_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# NEURON: bAC217_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate bAC217_biophys
#                             ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file(1, "biophysics.hoc")
# 	1
# 	1
# 	1
# template bAC217_L5_MC_cc2a170ef6 exist already
# Cell L5_MC_bAC217_1 extracellular spikes to be simulated
# Cell: L5_MC_bAC217_1 Progress: [1/50]
# Cell: L5_MC_bAC217_1 Progress: [2/50]
# Cell: L5_MC_bAC217_1 Progress: [3/50]
# Cell: L5_MC_bAC217_1 Progress: [4/50]
# Cell: L5_MC_bAC217_1 Progress: [5/50]
# Cell: L5_MC_bAC217_1 Progress: [6/50]
# Cell: L5_MC_bAC217_1 Progress: [7/50]
# Cell: L5_MC_bAC217_1 Progress: [8/50]
# Cell: L5_MC_bAC217_1 Progress: [9/50]
# Cell: L5_MC_bAC217_1 Progress: [10/50]
# Cell: L5_MC_bAC217_1 Progress: [11/50]
# Cell: L5_MC_bAC217_1 Progress: [12/50]
# Cell: L5_MC_bAC217_1 Progress: [13/50]
# Cell: L5_MC_bAC217_1 Progress: [14/50]
# Cell: L5_MC_bAC217_1 Progress: [15/50]
# Cell: L5_MC_bAC217_1 Progress: [16/50]
# Cell: L5_MC_bAC217_1 Progress: [17/50]
# Cell: L5_MC_bAC217_1 Progress: [18/50]
# Cell: L5_MC_bAC217_1 Progress: [19/50]
# Cell: L5_MC_bAC217_1 Progress: [20/50]
# Cell: L5_MC_bAC217_1 Progress: [21/50]
# Cell: L5_MC_bAC217_1 Progress: [22/50]
# Cell: L5_MC_bAC217_1 Progress: [23/50]
# Cell: L5_MC_bAC217_1 Progress: [24/50]
# Cell: L5_MC_bAC217_1 Progress: [25/50]
# Cell: L5_MC_bAC217_1 Progress: [26/50]
# Cell: L5_MC_bAC217_1 Progress: [27/50]
# Cell: L5_MC_bAC217_1 Progress: [28/50]
# Cell: L5_MC_bAC217_1 Progress: [29/50]
# Cell: L5_MC_bAC217_1 Progress: [30/50]
# Cell: L5_MC_bAC217_1 Progress: [31/50]
# Cell: L5_MC_bAC217_1 Progress: [32/50]
# Cell: L5_MC_bAC217_1 Progress: [33/50]
# Cell: L5_MC_bAC217_1 Progress: [34/50]
# Cell: L5_MC_bAC217_1 Progress: [35/50]
# Cell: L5_MC_bAC217_1 Progress: [36/50]
# Cell: L5_MC_bAC217_1 Progress: [37/50]
# Cell: L5_MC_bAC217_1 Progress: [38/50]
# Cell: L5_MC_bAC217_1 Progress: [39/50]
# Cell: L5_MC_bAC217_1 Progress: [40/50]
# Cell: L5_MC_bAC217_1 Progress: [41/50]
# Cell: L5_MC_bAC217_1 Progress: [42/50]
# Cell: L5_MC_bAC217_1 Progress: [43/50]
# Cell: L5_MC_bAC217_1 Progress: [44/50]
# Cell: L5_MC_bAC217_1 Progress: [45/50]
# Cell: L5_MC_bAC217_1 Progress: [46/50]
# Cell: L5_MC_bAC217_1 Progress: [47/50]
# Cell: L5_MC_bAC217_1 Progress: [48/50]
# Cell: L5_MC_bAC217_1 Progress: [49/50]
# Cell: L5_MC_bAC217_1 Progress: [50/50]
# Done generating EAPs for L5_MC_bAC217_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_NBC_bAC217_1 7/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_NBC_bAC217_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_NBC_bAC217_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# 	1
# 	1
# 	1
# template bAC217_L5_NBC_2db880c523 exist already
# NEURON: bAC217_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate bAC217_biophys
#                             ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file(1, "biophysics.hoc")
# Cell L5_NBC_bAC217_1 extracellular spikes to be simulated
# Cell: L5_NBC_bAC217_1 Progress: [1/50]
# Cell: L5_NBC_bAC217_1 Progress: [2/50]
# Cell: L5_NBC_bAC217_1 Progress: [3/50]
# Cell: L5_NBC_bAC217_1 Progress: [4/50]
# Cell: L5_NBC_bAC217_1 Progress: [5/50]
# Cell: L5_NBC_bAC217_1 Progress: [6/50]
# Cell: L5_NBC_bAC217_1 Progress: [7/50]
# Cell: L5_NBC_bAC217_1 Progress: [8/50]
# Cell: L5_NBC_bAC217_1 Progress: [9/50]
# Cell: L5_NBC_bAC217_1 Progress: [10/50]
# Cell: L5_NBC_bAC217_1 Progress: [11/50]
# Cell: L5_NBC_bAC217_1 Progress: [12/50]
# Cell: L5_NBC_bAC217_1 Progress: [13/50]
# Cell: L5_NBC_bAC217_1 Progress: [14/50]
# Cell: L5_NBC_bAC217_1 Progress: [15/50]
# Cell: L5_NBC_bAC217_1 Progress: [16/50]
# Cell: L5_NBC_bAC217_1 Progress: [17/50]
# Cell: L5_NBC_bAC217_1 Progress: [18/50]
# Cell: L5_NBC_bAC217_1 Progress: [19/50]
# Cell: L5_NBC_bAC217_1 Progress: [20/50]
# Cell: L5_NBC_bAC217_1 Progress: [21/50]
# Cell: L5_NBC_bAC217_1 Progress: [22/50]
# Cell: L5_NBC_bAC217_1 Progress: [23/50]
# Cell: L5_NBC_bAC217_1 Progress: [24/50]
# Cell: L5_NBC_bAC217_1 Progress: [25/50]
# Cell: L5_NBC_bAC217_1 Progress: [26/50]
# Cell: L5_NBC_bAC217_1 Progress: [27/50]
# Cell: L5_NBC_bAC217_1 Progress: [28/50]
# Cell: L5_NBC_bAC217_1 Progress: [29/50]
# Cell: L5_NBC_bAC217_1 Progress: [30/50]
# Cell: L5_NBC_bAC217_1 Progress: [31/50]
# Cell: L5_NBC_bAC217_1 Progress: [32/50]
# Cell: L5_NBC_bAC217_1 Progress: [33/50]
# Cell: L5_NBC_bAC217_1 Progress: [34/50]
# Cell: L5_NBC_bAC217_1 Progress: [35/50]
# Cell: L5_NBC_bAC217_1 Progress: [36/50]
# Cell: L5_NBC_bAC217_1 Progress: [37/50]
# Cell: L5_NBC_bAC217_1 Progress: [38/50]
# Cell: L5_NBC_bAC217_1 Progress: [39/50]
# Cell: L5_NBC_bAC217_1 Progress: [40/50]
# Cell: L5_NBC_bAC217_1 Progress: [41/50]
# Cell: L5_NBC_bAC217_1 Progress: [42/50]
# Cell: L5_NBC_bAC217_1 Progress: [43/50]
# Cell: L5_NBC_bAC217_1 Progress: [44/50]
# Cell: L5_NBC_bAC217_1 Progress: [45/50]
# Cell: L5_NBC_bAC217_1 Progress: [46/50]
# Cell: L5_NBC_bAC217_1 Progress: [47/50]
# Cell: L5_NBC_bAC217_1 Progress: [48/50]
# Cell: L5_NBC_bAC217_1 Progress: [49/50]
# Cell: L5_NBC_bAC217_1 Progress: [50/50]
# Done generating EAPs for L5_NBC_bAC217_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_NGC_bNAC219_1 8/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_NGC_bNAC219_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_NGC_bNAC219_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# 	1
# 	1
# 	1
# template bNAC219_L5_NGC_6186b7e85e exist already
# Cell L5_NGC_bNAC219_1 extracellular spikes to be simulated
# Cell: L5_NGC_bNAC219_1 Progress: [1/50]
# Cell: L5_NGC_bNAC219_1 Progress: [2/50]
# Cell: L5_NGC_bNAC219_1 Progress: [3/50]
# Cell: L5_NGC_bNAC219_1 Progress: [4/50]
# Cell: L5_NGC_bNAC219_1 Progress: [5/50]
# Cell: L5_NGC_bNAC219_1 Progress: [6/50]
# Cell: L5_NGC_bNAC219_1 Progress: [7/50]
# Cell: L5_NGC_bNAC219_1 Progress: [8/50]
# Cell: L5_NGC_bNAC219_1 Progress: [9/50]
# Cell: L5_NGC_bNAC219_1 Progress: [10/50]
# Cell: L5_NGC_bNAC219_1 Progress: [11/50]
# Cell: L5_NGC_bNAC219_1 Progress: [12/50]
# Cell: L5_NGC_bNAC219_1 Progress: [13/50]
# Cell: L5_NGC_bNAC219_1 Progress: [14/50]
# Cell: L5_NGC_bNAC219_1 Progress: [15/50]
# Cell: L5_NGC_bNAC219_1 Progress: [16/50]
# Cell: L5_NGC_bNAC219_1 Progress: [17/50]
# Cell: L5_NGC_bNAC219_1 Progress: [18/50]
# Cell: L5_NGC_bNAC219_1 Progress: [19/50]
# Cell: L5_NGC_bNAC219_1 Progress: [20/50]
# Cell: L5_NGC_bNAC219_1 Progress: [21/50]
# Cell: L5_NGC_bNAC219_1 Progress: [22/50]
# Cell: L5_NGC_bNAC219_1 Progress: [23/50]
# Cell: L5_NGC_bNAC219_1 Progress: [24/50]
# Cell: L5_NGC_bNAC219_1 Progress: [25/50]
# Cell: L5_NGC_bNAC219_1 Progress: [26/50]
# Cell: L5_NGC_bNAC219_1 Progress: [27/50]
# Cell: L5_NGC_bNAC219_1 Progress: [28/50]
# Cell: L5_NGC_bNAC219_1 Progress: [29/50]
# Cell: L5_NGC_bNAC219_1 Progress: [30/50]
# Cell: L5_NGC_bNAC219_1 Progress: [31/50]
# Cell: L5_NGC_bNAC219_1 Progress: [32/50]
# Cell: L5_NGC_bNAC219_1 Progress: [33/50]
# Cell: L5_NGC_bNAC219_1 Progress: [34/50]
# Cell: L5_NGC_bNAC219_1 Progress: [35/50]
# Cell: L5_NGC_bNAC219_1 Progress: [36/50]
# Cell: L5_NGC_bNAC219_1 Progress: [37/50]
# Cell: L5_NGC_bNAC219_1 Progress: [38/50]
# Cell: L5_NGC_bNAC219_1 Progress: [39/50]
# Cell: L5_NGC_bNAC219_1 Progress: [40/50]
# Cell: L5_NGC_bNAC219_1 Progress: [41/50]
# Cell: L5_NGC_bNAC219_1 Progress: [42/50]
# Cell: L5_NGC_bNAC219_1 Progress: [43/50]
# Cell: L5_NGC_bNAC219_1 Progress: [44/50]
# Cell: L5_NGC_bNAC219_1 Progress: [45/50]
# Cell: L5_NGC_bNAC219_1 Progress: [46/50]
# Cell: L5_NGC_bNAC219_1 Progress: [47/50]
# Cell: L5_NGC_bNAC219_1 Progress: [48/50]
# Cell: L5_NGC_bNAC219_1 Progress: [49/50]
# Cell: L5_NGC_bNAC219_1 Progress: [50/50]
# Done generating EAPs for L5_NGC_bNAC219_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_SBC_bNAC219_1 9/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_SBC_bNAC219_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_SBC_bNAC219_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# 	1
# 	1
# 	1
# template bNAC219_L5_SBC_77ab259b7f exist already
# NEURON: bNAC219_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate bNAC219_biophys
#                              ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file(1, "biophysics.hoc")
# Cell L5_SBC_bNAC219_1 extracellular spikes to be simulated
# Cell: L5_SBC_bNAC219_1 Progress: [1/50]
# Cell: L5_SBC_bNAC219_1 Progress: [2/50]
# Cell: L5_SBC_bNAC219_1 Progress: [3/50]
# Cell: L5_SBC_bNAC219_1 Progress: [4/50]
# Cell: L5_SBC_bNAC219_1 Progress: [5/50]
# Cell: L5_SBC_bNAC219_1 Progress: [6/50]
# Cell: L5_SBC_bNAC219_1 Progress: [7/50]
# Cell: L5_SBC_bNAC219_1 Progress: [8/50]
# Cell: L5_SBC_bNAC219_1 Progress: [9/50]
# Cell: L5_SBC_bNAC219_1 Progress: [10/50]
# Cell: L5_SBC_bNAC219_1 Progress: [11/50]
# Cell: L5_SBC_bNAC219_1 Progress: [12/50]
# Cell: L5_SBC_bNAC219_1 Progress: [13/50]
# Cell: L5_SBC_bNAC219_1 Progress: [14/50]
# Cell: L5_SBC_bNAC219_1 Progress: [15/50]
# Cell: L5_SBC_bNAC219_1 Progress: [16/50]
# Cell: L5_SBC_bNAC219_1 Progress: [17/50]
# Cell: L5_SBC_bNAC219_1 Progress: [18/50]
# Cell: L5_SBC_bNAC219_1 Progress: [19/50]
# Cell: L5_SBC_bNAC219_1 Progress: [20/50]
# Cell: L5_SBC_bNAC219_1 Progress: [21/50]
# Cell: L5_SBC_bNAC219_1 Progress: [22/50]
# Cell: L5_SBC_bNAC219_1 Progress: [23/50]
# Cell: L5_SBC_bNAC219_1 Progress: [24/50]
# Cell: L5_SBC_bNAC219_1 Progress: [25/50]
# Cell: L5_SBC_bNAC219_1 Progress: [26/50]
# Cell: L5_SBC_bNAC219_1 Progress: [27/50]
# Cell: L5_SBC_bNAC219_1 Progress: [28/50]
# Cell: L5_SBC_bNAC219_1 Progress: [29/50]
# Cell: L5_SBC_bNAC219_1 Progress: [30/50]
# Cell: L5_SBC_bNAC219_1 Progress: [31/50]
# Cell: L5_SBC_bNAC219_1 Progress: [32/50]
# Cell: L5_SBC_bNAC219_1 Progress: [33/50]
# Cell: L5_SBC_bNAC219_1 Progress: [34/50]
# Cell: L5_SBC_bNAC219_1 Progress: [35/50]
# Cell: L5_SBC_bNAC219_1 Progress: [36/50]
# Cell: L5_SBC_bNAC219_1 Progress: [37/50]
# Cell: L5_SBC_bNAC219_1 Progress: [38/50]
# Cell: L5_SBC_bNAC219_1 Progress: [39/50]
# Cell: L5_SBC_bNAC219_1 Progress: [40/50]
# Cell: L5_SBC_bNAC219_1 Progress: [41/50]
# Cell: L5_SBC_bNAC219_1 Progress: [42/50]
# Cell: L5_SBC_bNAC219_1 Progress: [43/50]
# Cell: L5_SBC_bNAC219_1 Progress: [44/50]
# Cell: L5_SBC_bNAC219_1 Progress: [45/50]
# Cell: L5_SBC_bNAC219_1 Progress: [46/50]
# Cell: L5_SBC_bNAC219_1 Progress: [47/50]
# Cell: L5_SBC_bNAC219_1 Progress: [48/50]
# Cell: L5_SBC_bNAC219_1 Progress: [49/50]
# Cell: L5_SBC_bNAC219_1 Progress: [50/50]
# Done generating EAPs for L5_SBC_bNAC219_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_STPC_cADpyr232_1 10/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_STPC_cADpyr232_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_STPC_cADpyr232_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# 	1
# 	1
# 	1
# template cADpyr232_L5_STPC_d16b0be14e exist already
# Cell L5_STPC_cADpyr232_1 extracellular spikes to be simulated
# Cell: L5_STPC_cADpyr232_1 Progress: [1/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [2/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [3/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [4/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [5/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [6/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [7/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [8/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [9/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [10/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [11/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [12/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [13/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [14/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [15/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [16/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [17/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [18/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [19/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [20/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [21/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [22/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [23/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [24/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [25/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [26/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [27/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [28/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [29/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [30/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [31/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [32/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [33/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [34/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [35/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [36/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [37/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [38/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [39/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [40/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [41/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [42/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [43/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [44/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [45/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [46/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [47/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [48/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [49/50]
# Cell: L5_STPC_cADpyr232_1 Progress: [50/50]
# Done generating EAPs for L5_STPC_cADpyr232_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_TTPC1_cADpyr232_1 11/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_TTPC1_cADpyr232_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_TTPC1_cADpyr232_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# 	1
# 	1
# 	1
# template cADpyr232_L5_TTPC1_0fb1ca4724 exist already
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file(1, "biophysics.hoc")
# Cell L5_TTPC1_cADpyr232_1 extracellular spikes to be simulated
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [2/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [3/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [4/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [5/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [6/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [7/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [8/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [9/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [10/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [11/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [12/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [13/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [14/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [15/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [16/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [17/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [18/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [19/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [20/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [21/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [22/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [23/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [24/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [25/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [26/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [27/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [28/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [29/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [30/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [31/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [32/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [33/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [34/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [35/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [36/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [37/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [38/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [39/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [40/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [41/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [42/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [43/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [44/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [45/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [46/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [47/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [48/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [49/50]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [50/50]
# Done generating EAPs for L5_TTPC1_cADpyr232_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_TTPC2_cADpyr232_1 12/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_TTPC2_cADpyr232_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_TTPC2_cADpyr232_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# 	1
# 	1
# 	1
# template cADpyr232_L5_TTPC2_8052133265 exist already
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file(1, "biophysics.hoc")
# Cell L5_TTPC2_cADpyr232_1 extracellular spikes to be simulated
# Cell: L5_TTPC2_cADpyr232_1 Progress: [1/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [2/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [3/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [4/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [5/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [6/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [7/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [8/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [9/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [10/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [11/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [12/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [13/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [14/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [15/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [16/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [17/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [18/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [19/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [20/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [21/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [22/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [23/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [24/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [25/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [26/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [27/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [28/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [29/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [30/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [31/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [32/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [33/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [34/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [35/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [36/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [37/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [38/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [39/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [40/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [41/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [42/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [43/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [44/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [45/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [46/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [47/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [48/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [49/50]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [50/50]
# Done generating EAPs for L5_TTPC2_cADpyr232_1
#
#
#  /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_UTPC_cADpyr232_1 13/13
#
#
# Intracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_UTPC_cADpyr232_1
#
#
#
# Cell has already be simulated. Using stored membrane currents
#
#
#
# Extracellular simulation: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/L5_UTPC_cADpyr232_1
# Mechanisms already loaded from path: /mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/development/neural-signal-processing/data/mearec/cell_models/bbp/mods.  Aborting.
# 	1
# 	1
# 	1
# template cADpyr232_L5_UTPC_5e3840b51e exist already
# NEURON: cADpyr232_biophys : a template cannot be redefined
#  in biophysics.hoc near line 33
#  begintemplate cADpyr232_biophys
#                                ^
#         xopen("biophysics.hoc")
#       execute1("{xopen("bi...")
#     load_file(1, "biophysics.hoc")
# Cell L5_UTPC_cADpyr232_1 extracellular spikes to be simulated
# Cell: L5_UTPC_cADpyr232_1 Progress: [1/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [2/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [3/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [4/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [5/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [6/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [7/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [8/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [9/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [10/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [11/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [12/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [13/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [14/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [15/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [16/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [17/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [18/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [19/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [20/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [21/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [22/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [23/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [24/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [25/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [26/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [27/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [28/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [29/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [30/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [31/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [32/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [33/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [34/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [35/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [36/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [37/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [38/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [39/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [40/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [41/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [42/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [43/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [44/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [45/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [46/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [47/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [48/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [49/50]
# Cell: L5_UTPC_cADpyr232_1 Progress: [50/50]
# Done generating EAPs for L5_UTPC_cADpyr232_1
#
#
#
# Simulation time: 574.5204682350159
#
#
#
# Models generated
#
# Saved  templates in /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_29-09-2021_18-16.h5

# %% [markdown]
# Once generated in a custom location, then it follows to recording generation

# %% [markdown]
# ## Recordings generation
#
# For the recordings generation, it will be considered a set of noise_levels to perform the evaluation for different values of noise.

# %%
noise_level = [5, 10, 15, 20, 25, 50, 75]
for noise in noise_level:
     generate_recordings(config_folder=config["config_folder"],
                        templates_folder=config["templates_folder"],
                        recordings_folder=config["recordings_folder"],
                        verbose=True, noise_level=noise)
# Out:
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  5
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.12013483047485352
# Creating time jittering
# Elapsed jitter time: 0.384793758392334
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  2.105365837000136
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_5uV_32000Hz_2021-09-29_18-20.h5
#
# Deleted /tmp/tmpupkkpat9
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  10
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.12370824813842773
# Creating time jittering
# Elapsed jitter time: 0.3419210910797119
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  2.014132382999378
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_10uV_32000Hz_2021-09-29_18-20.h5
#
# Deleted /tmp/tmpen9hxxqn
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  15
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.14513063430786133
# Creating time jittering
# Elapsed jitter time: 0.313138484954834
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.9509815860001254
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_15uV_32000Hz_2021-09-29_18-20.h5
#
# Deleted /tmp/tmpzh4nyo3i
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  20
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.14717602729797363
# Creating time jittering
# Elapsed jitter time: 0.3381624221801758
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.9722288660013874
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_20uV_32000Hz_2021-09-29_18-20.h5
#
# Deleted /tmp/tmpuq_kdt5t
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  25
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.12070322036743164
# Creating time jittering
# Elapsed jitter time: 0.2780609130859375
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.8574721579971083
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_25uV_32000Hz_2021-09-29_18-20.h5
#
# Deleted /tmp/tmptsj01yqi
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  50
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.11863422393798828
# Creating time jittering
# Elapsed jitter time: 0.287534236907959
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.9255937390007603
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_50uV_32000Hz_2021-09-29_18-20.h5
#
# Deleted /tmp/tmp8if_bj6n
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  75
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.1656966209411621
# Creating time jittering
# Elapsed jitter time: 0.378523588180542
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  2.081058652998763
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_75uV_32000Hz_2021-09-29_18-20.h5
#
# Deleted /tmp/tmpxzj53f_7

# %% [markdown]
# Once generated, the function `loadRecordings` could be used to load the recordings and plot them

# %%
recgen_list = [load_recordings(datafolder=config["recordings_folder"],
                         verbose=True, noise_level=noise) for noise in noise_level]
# Out:
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_5uV_32000Hz_2021-09-29_18-20.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_10uV_32000Hz_2021-09-29_18-20.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_15uV_32000Hz_2021-09-29_18-20.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_20uV_32000Hz_2021-09-29_18-20.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_25uV_32000Hz_2021-09-29_18-20.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_50uV_32000Hz_2021-09-29_18-20.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_75uV_32000Hz_2021-09-29_18-20.h5
# Loading recordings...
# Done loading recordings...

# %%
# %matplotlib inline

# %%
import MEArec as mr

# %%
for recgen in recgen_list:
    mr.plot_recordings(recgen=recgen)
    current_noise_level = recgen.info["recordings"]["noise_level"]
    print(f"Noise level={current_noise_level}")
# Out:
# Noise level=5
# Noise level=10
# Noise level=15
# Noise level=20
# Noise level=25
# Noise level=50
# Noise level=75

# %%
for recgen in recgen_list:
    mr.plot_rasters(recgen.spiketrains)
    current_noise_level = recgen.info["recordings"]["noise_level"]
    print(f"Noise level={current_noise_level}")
# Out:
# Noise level=5
# Noise level=10
# Noise level=15
# Noise level=20
# Noise level=25
# Noise level=50
# Noise level=75

# %%
from eapprocessor.plot.signals import plotTransientRecordings

# %%
for recgen in recgen_list:
    plotTransientRecordings(recgen, channels=range(1))

# %% [markdown]
# ## Recordings generation for different frequencies

# %%
fs_list = [32000, 24000, 20000, 16000]
for fs in fs_list:
    for noise in noise_level:
         generate_recordings(config_folder=config["config_folder"],
                            templates_folder=config["templates_folder"],
                            recordings_folder=config["recordings_folder"],
                            verbose=True, noise_level=noise, fs=fs)
# Out:
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  5
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.1135568618774414
# Creating time jittering
# Elapsed jitter time: 0.31507182121276855
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  2.0431778199999826
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_5uV_32000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpunrr3hyn
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  10
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.15837693214416504
# Creating time jittering
# Elapsed jitter time: 0.2795896530151367
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.9089513090002583
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_10uV_32000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpwcavourz
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  15
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.1375107765197754
# Creating time jittering
# Elapsed jitter time: 0.3362691402435303
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  2.0528137289984443
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_15uV_32000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmp621pln_3
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  20
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.12621283531188965
# Creating time jittering
# Elapsed jitter time: 0.3009796142578125
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.8893503090002923
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_20uV_32000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpr1by2873
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  25
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.16053318977355957
# Creating time jittering
# Elapsed jitter time: 0.32799649238586426
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.9206545050001296
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_25uV_32000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmp7u889jfy
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  50
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.18313097953796387
# Creating time jittering
# Elapsed jitter time: 0.3184242248535156
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.9515119399984542
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_50uV_32000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpdaa0p4f1
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  75
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.14393091201782227
# Creating time jittering
# Elapsed jitter time: 0.3343813419342041
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.8963464589978685
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_75uV_32000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpefyue1p7
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  5
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.12206768989562988
# Elapsed resample time: 0.006332874298095703
# Creating time jittering
# Elapsed jitter time: 0.21036314964294434
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.4857686830000603
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_5uV_24000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpessh77c_
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  10
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.12039613723754883
# Elapsed resample time: 0.006598472595214844
# Creating time jittering
# Elapsed jitter time: 0.19748616218566895
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.4465857020004478
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_10uV_24000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmp2jpwe4ck
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  15
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.11459469795227051
# Elapsed resample time: 0.006484031677246094
# Creating time jittering
# Elapsed jitter time: 0.20581483840942383
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.505468204999488
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_15uV_24000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmplb9e41d9
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  20
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.10831713676452637
# Elapsed resample time: 0.008684158325195312
# Creating time jittering
# Elapsed jitter time: 0.20272064208984375
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.4915932259973488
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_20uV_24000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmp6n1x0eqx
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  25
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.11261892318725586
# Elapsed resample time: 0.007998228073120117
# Creating time jittering
# Elapsed jitter time: 0.19708824157714844
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.4897789229980845
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_25uV_24000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpgtmoi6n3
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  50
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.11365151405334473
# Elapsed resample time: 0.007695674896240234
# Creating time jittering
# Elapsed jitter time: 0.19554471969604492
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.429912071002036
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_50uV_24000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpr2ryndzl
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  75
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.11767220497131348
# Elapsed resample time: 0.007256984710693359
# Creating time jittering
# Elapsed jitter time: 0.22369170188903809
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.5002136449984391
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_75uV_24000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpxrnqyr37
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  5
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.13695669174194336
# Elapsed resample time: 0.01120305061340332
# Creating time jittering
# Elapsed jitter time: 0.2745633125305176
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.4564299330013455
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_5uV_20000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpjcrcv9v7
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  10
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.10992240905761719
# Elapsed resample time: 0.008033275604248047
# Creating time jittering
# Elapsed jitter time: 0.17206883430480957
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.2785644159994263
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_10uV_20000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpgctj3kd8
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  15
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.16270232200622559
# Elapsed resample time: 0.0078051090240478516
# Creating time jittering
# Elapsed jitter time: 0.21013474464416504
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.4951211719999264
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_15uV_20000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpwu0x18xy
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  20
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.11457657814025879
# Elapsed resample time: 0.0068051815032958984
# Creating time jittering
# Elapsed jitter time: 0.1807999610900879
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.3005439179978566
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_20uV_20000Hz_2021-09-29_18-29.h5
#
# Deleted /tmp/tmpl6xd1ydk
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  25
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.13254284858703613
# Elapsed resample time: 0.006680011749267578
# Creating time jittering
# Elapsed jitter time: 0.20776653289794922
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.3261575809992792
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_25uV_20000Hz_2021-09-29_18-30.h5
#
# Deleted /tmp/tmpsizzubfb
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  50
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.12010002136230469
# Elapsed resample time: 0.006670951843261719
# Creating time jittering
# Elapsed jitter time: 0.18747353553771973
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.3304687419986294
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_50uV_20000Hz_2021-09-29_18-30.h5
#
# Deleted /tmp/tmpqko8a1rq
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  75
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.1203761100769043
# Elapsed resample time: 0.00673675537109375
# Creating time jittering
# Elapsed jitter time: 0.18363547325134277
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.3040403819977655
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_75uV_20000Hz_2021-09-29_18-30.h5
#
# ...
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  5
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.10360240936279297
# Elapsed resample time: 0.005888462066650391
# Creating time jittering
# Elapsed jitter time: 0.14535975456237793
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.1015665369995986
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_5uV_16000Hz_2021-09-29_18-30.h5
#
# Deleted /tmp/tmp1gyfp8qk
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  10
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.1093907356262207
# Elapsed resample time: 0.006864786148071289
# Creating time jittering
# Elapsed jitter time: 0.14789271354675293
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.1092385120027757
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_10uV_16000Hz_2021-09-29_18-30.h5
#
# Deleted /tmp/tmpqg1v41w2
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  15
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.17904925346374512
# Elapsed resample time: 0.007712125778198242
# Creating time jittering
# Elapsed jitter time: 0.23710131645202637
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.393880793999415
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_15uV_16000Hz_2021-09-29_18-30.h5
#
# Deleted /tmp/tmprzc9xvxe
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  20
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.15123248100280762
# Elapsed resample time: 0.006133317947387695
# Creating time jittering
# Elapsed jitter time: 0.19446444511413574
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.2560142439979245
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_20uV_16000Hz_2021-09-29_18-30.h5
#
# Deleted /tmp/tmp_v7sdwpx
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  25
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.11002969741821289
# Elapsed resample time: 0.007979631423950195
# Creating time jittering
# Elapsed jitter time: 0.1433403491973877
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.106336689001182
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_25uV_16000Hz_2021-09-29_18-30.h5
#
# Deleted /tmp/tmpled579o8
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  50
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.14465880393981934
# Elapsed resample time: 0.006655693054199219
# Creating time jittering
# Elapsed jitter time: 0.23685383796691895
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.3890112580011191
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_50uV_16000Hz_2021-09-29_18-30.h5
#
# Deleted /tmp/tmpt4wh3_c0
# {'spiketrains': {'n_exc': 7, 'n_inh': 3, 'f_exc': 5, 'f_inh': 15, 'st_exc': 1, 'st_inh': 3, 'min_rate': 0.5, 'ref_per': 2, 'process': 'poisson', 'gamma_shape': 2, 't_start': 0, 'duration': 10}, 'cell_types': {'excitatory': ['PC', 'SS', 'SP'], 'inhibitory': ['AC', 'BP', 'BC', 'BTC', 'ChC', 'DBC', 'MC', 'NGC']}, 'seeds': {'spiketrains': 100, 'templates': 100, 'convolution': 100, 'noise': 100}, 'templates': {'min_dist': 25, 'min_amp': 50, 'max_amp': 300, 'n_overlap_pairs': None, 'xlim': None, 'ylim': None, 'zlim': None, 'overlap_threshold': 0.9, 'n_jitters': 10, 'upsample': 8, 'pad_len': [3, 3]}, 'recordings': {'fs': None, 'dtype': 'float32', 'overlap': False, 'extract_waveforms': False, 'sync_rate': None, 'sync_jitt': 1, 'chunk_duration': 0, 'modulation': 'electrode', 'sdrand': 0.05, 'bursting': False, 'bursting_units': None, 'exp_decay': 0.2, 'n_burst_spikes': 10, 'max_burst_duration': 100, 'shape_mod': False, 'shape_stretch': 30.0, 'n_bursting': None, 'noise_level': 10, 'noise_mode': 'uncorrelated', 'noise_color': False, 'noise_half_distance': 30, 'far_neurons_n': 300, 'far_neurons_max_amp': 10, 'far_neurons_noise_floor': 0.5, 'far_neurons_exc_inh_ratio': 0.8, 'color_peak': 300, 'color_q': 2, 'color_noise_floor': 1, 'filter': True, 'filter_cutoff': [300, 6000], 'filter_order': 3, 'drifting': False, 'drift_mode': 'slow', 'n_drifting': None, 'preferred_dir': [0, 0, 1], 'angle_tol': 15, 'slow_drift_velocity': 5, 'fast_drift_period': 10, 'fast_drift_max_jump': 20, 'fast_drift_min_jump': 5, 't_start_drift': 0}}
# Loading templates...
# Loading file /mnt/Archivos/data/output/templates/physrot/templates_50_Neuronexus-32_30-08-2021_11-44.h5
# Done loading templates...
# Spiketrains seed:  100
# Noise Level  75
# Templates selection seed:  100
# Selecting cells
# Padding template edges
# Elapsed pad time: 0.1272120475769043
# Elapsed resample time: 0.006323575973510742
# Creating time jittering
# Elapsed jitter time: 0.16132354736328125
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  100
# Electrode modulaton
# Adding noise
# Noise seed:  100
# Filtering
# Band-pass cutoff [ 300. 6000.] Hz
# Elapsed time:  1.2160597900001449
#
# Saved recordings in /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_75uV_16000Hz_2021-09-29_18-30.h5
#
# Deleted /tmp/tmp7mgwivvh

# %%
all_recgen_list = [[load_recordings(datafolder=config["recordings_folder"],
                verbose=True, noise_level=noise, fs=fs) for noise in noise_level]
               for fs in fs_list]
# Out:
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_5uV_32000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_10uV_32000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_15uV_32000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_20uV_32000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_25uV_32000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_50uV_32000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_75uV_32000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_5uV_24000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_10uV_24000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_15uV_24000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_20uV_24000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_25uV_24000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_50uV_24000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_75uV_24000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_5uV_20000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_10uV_20000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_15uV_20000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_20uV_20000Hz_2021-09-29_18-29.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_25uV_20000Hz_2021-09-29_18-30.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_50uV_20000Hz_2021-09-29_18-30.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_75uV_20000Hz_2021-09-29_18-30.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_5uV_16000Hz_2021-09-29_18-30.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_10uV_16000Hz_2021-09-29_18-30.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_15uV_16000Hz_2021-09-29_18-30.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_20uV_16000Hz_2021-09-29_18-30.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_25uV_16000Hz_2021-09-29_18-30.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_50uV_16000Hz_2021-09-29_18-30.h5
# Loading recordings...
# Done loading recordings...
# Loading file /mnt/Archivos/data/output/recordings/recordings_10cells_Neuronexus-32_10.0_75uV_16000Hz_2021-09-29_18-30.h5
# Loading recordings...
# Done loading recordings...

# %% [markdown]
# Plotting for 16kHz sampling frecuency:

# %%
for recgen in all_recgen_list[-1]:
    plotTransientRecordings(recgen, channels=range(1))
