# %% [markdown]
# # Threshold Evaluation for multiple bw values
#
# This stage evaluates the results with the detector, comparing them with the original spiketrains. To do this, it requires to load the NEO files for each value of resolution.

# %% [markdown]
# ## Loading NEO files

# %%
# %load_ext autoreload
# %autoreload 2

# %%
BASE_DIR="/mnt/Data/data"

# %%
from eapprocessor.tools.load import load_neo, load_count_evaluation, get_evaluation_files

# %%
noise_levels = [5, 15, 25]
resolutions = [12,10,9,8,7,6]
neofolders = [
    f"{BASE_DIR}/output/preprocessor",
    f"{BASE_DIR}/output-bw-300-3000/preprocessor",
    f"{BASE_DIR}/output-bw-300-1000/preprocessor"
]
fs=20000

# %%
neo_list=[]
neo_files=[]
for neofolder in neofolders:
    neo_list_bw = []
    neo_files_bw = []
    for resolution in resolutions:
        neo_list_resolution = []
        neo_files_resolution =[]
        for noise_level in noise_levels:
            neo_dict, file = load_neo(neofolder, verbose=True, resolution=resolution, 
                               noise_level=noise_level, fs=fs)
            neo_list_resolution += [neo_dict]
            neo_files_resolution += [file]

        neo_list_bw += [neo_list_resolution]
        neo_files_bw += [neo_files_resolution]
    neo_list += [neo_list_bw]
    neo_files += [neo_files_bw]
# Out:
# Search for pattern: *_12_5uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_12_5uV_20000Hz_2021-12-02_17-29.h5
# Search for pattern: *_12_15uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_12_15uV_20000Hz_2021-12-02_17-29.h5
# Search for pattern: *_12_25uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_12_25uV_20000Hz_2021-12-02_17-29.h5
# Search for pattern: *_10_5uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_10_5uV_20000Hz_2021-12-02_17-30.h5
# Search for pattern: *_10_15uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_10_15uV_20000Hz_2021-12-02_17-31.h5
# Search for pattern: *_10_25uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_10_25uV_20000Hz_2021-12-02_17-31.h5
# Search for pattern: *_9_5uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_9_5uV_20000Hz_2021-12-02_17-32.h5
# Search for pattern: *_9_15uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_9_15uV_20000Hz_2021-12-02_17-32.h5
# Search for pattern: *_9_25uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_9_25uV_20000Hz_2021-12-02_17-32.h5
# Search for pattern: *_8_5uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_8_5uV_20000Hz_2021-12-02_17-33.h5
# Search for pattern: *_8_15uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_8_15uV_20000Hz_2021-12-02_17-34.h5
# Search for pattern: *_8_25uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_8_25uV_20000Hz_2021-12-02_17-34.h5
# Search for pattern: *_7_5uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_7_5uV_20000Hz_2021-12-02_17-35.h5
# Search for pattern: *_7_15uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_7_15uV_20000Hz_2021-12-02_17-35.h5
# Search for pattern: *_7_25uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_7_25uV_20000Hz_2021-12-02_17-35.h5
# Search for pattern: *_6_5uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_6_5uV_20000Hz_2021-12-02_17-36.h5
# Search for pattern: *_6_15uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_6_15uV_20000Hz_2021-12-02_17-37.h5
# Search for pattern: *_6_25uV_20000Hz*
# Loading file /mnt/Data/data/output/preprocessor/preprocessed_neo_6_25uV_20000Hz_2021-12-02_17-37.h5
# Search for pattern: *_12_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_12_5uV_20000Hz_2021-12-02_17-45.h5
# Search for pattern: *_12_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_12_15uV_20000Hz_2021-12-02_17-46.h5
# Search for pattern: *_12_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_12_25uV_20000Hz_2021-12-02_17-46.h5
# Search for pattern: *_10_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_10_5uV_20000Hz_2021-12-02_17-47.h5
# Search for pattern: *_10_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_10_15uV_20000Hz_2021-12-02_17-47.h5
# Search for pattern: *_10_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_10_25uV_20000Hz_2021-12-02_17-47.h5
# Search for pattern: *_9_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_9_5uV_20000Hz_2021-12-02_17-49.h5
# Search for pattern: *_9_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_9_15uV_20000Hz_2021-12-02_17-49.h5
# Search for pattern: *_9_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_9_25uV_20000Hz_2021-12-02_17-49.h5
# Search for pattern: *_8_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_8_5uV_20000Hz_2021-12-02_17-50.h5
# Search for pattern: *_8_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_8_15uV_20000Hz_2021-12-02_17-50.h5
# Search for pattern: *_8_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_8_25uV_20000Hz_2021-12-02_17-50.h5
# Search for pattern: *_7_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_7_5uV_20000Hz_2021-12-02_17-52.h5
# Search for pattern: *_7_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_7_15uV_20000Hz_2021-12-02_17-52.h5
# Search for pattern: *_7_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_7_25uV_20000Hz_2021-12-02_17-52.h5
# Search for pattern: *_6_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_6_5uV_20000Hz_2021-12-02_17-53.h5
# Search for pattern: *_6_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_6_15uV_20000Hz_2021-12-02_17-54.h5
# Search for pattern: *_6_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-3000/preprocessor/preprocessed_neo_6_25uV_20000Hz_2021-12-02_17-54.h5
# Search for pattern: *_12_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_12_5uV_20000Hz_2021-12-02_18-03.h5
# Search for pattern: *_12_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_12_15uV_20000Hz_2021-12-02_18-03.h5
# Search for pattern: *_12_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_12_25uV_20000Hz_2021-12-02_18-03.h5
# Search for pattern: *_10_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_10_5uV_20000Hz_2021-12-02_18-05.h5
# Search for pattern: *_10_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_10_15uV_20000Hz_2021-12-02_18-05.h5
# Search for pattern: *_10_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_10_25uV_20000Hz_2021-12-02_18-05.h5
# Search for pattern: *_9_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_9_5uV_20000Hz_2021-12-02_18-06.h5
# Search for pattern: *_9_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_9_15uV_20000Hz_2021-12-02_18-06.h5
# Search for pattern: *_9_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_9_25uV_20000Hz_2021-12-02_18-07.h5
# Search for pattern: *_8_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_8_5uV_20000Hz_2021-12-02_18-08.h5
# Search for pattern: *_8_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_8_15uV_20000Hz_2021-12-02_18-08.h5
# Search for pattern: *_8_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_8_25uV_20000Hz_2021-12-02_18-08.h5
# Search for pattern: *_7_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_7_5uV_20000Hz_2021-12-02_18-09.h5
# Search for pattern: *_7_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_7_15uV_20000Hz_2021-12-02_18-10.h5
# Search for pattern: *_7_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_7_25uV_20000Hz_2021-12-02_18-10.h5
# Search for pattern: *_6_5uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_6_5uV_20000Hz_2021-12-02_18-11.h5
# Search for pattern: *_6_15uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_6_15uV_20000Hz_2021-12-02_18-11.h5
# Search for pattern: *_6_25uV_20000Hz*
# Loading file /mnt/Data/data/output-bw-300-1000/preprocessor/preprocessed_neo_6_25uV_20000Hz_2021-12-02_18-11.h5

# %% [markdown]
# ## Exploring converted signals

# %%
from eapprocessor.plot.signals import plot_transient_converted, plot_transient_recordings, plot_transient_neo

# %%
plot_transient_recordings(neo_list[0][0]["recordings"], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_converted(neo_list[0][0], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_converted(neo_list[4][0], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_neo(neo_list[0][0], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_neo(neo_list[4][0], channels=[27], t_stop=0.1,marker='.--')

# %% [markdown]
# ## Getting evaluation files

# %%
evalfolders = [
    f"{BASE_DIR}/output/evaluator",
    f"{BASE_DIR}/output-bw-300-3000/evaluator",
    f"{BASE_DIR}/output-bw-300-1000/evaluator"
]

# %%
evaluator_files_dict_list = []
for idx, neo_files_bw in enumerate(neo_files):
    evaluator_files_dict_bw =[]
    for neo_files_resolution in neo_files_bw:
        evaluator_files_dict_list_resolution=[]
        for neo_file in neo_files_resolution: 
            file_dict = get_evaluation_files(evalfolders[idx],sourcefile=neo_file) 
            evaluator_files_dict_list_resolution += [file_dict]
        evaluator_files_dict_bw += [evaluator_files_dict_list_resolution]
    evaluator_files_dict_list+= [evaluator_files_dict_bw]
# Out:
# Search for pattern: *
# Filename found 3 files with source /mnt/Data/data/output/preprocessor/preprocessed_neo_12_5uV_20000Hz_2021-12-02_17-29.h5
# [PosixPath('/mnt/Data/data/output/evaluator/threshold_recordings_subset_50th_12_5uV_20000Hz_2021-12-02_19-00.h5'), PosixPath('/mnt/Data/data/output/evaluator/threshold_normalized_subset_50th_12_5uV_20000Hz_2021-12-02_19-00.h5'), PosixPath('/mnt/Data/data/output/evaluator/threshold_neo_subset_50th_12_5uV_20000Hz_2021-12-02_19-00.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Data/data/output/preprocessor/preprocessed_neo_12_15uV_20000Hz_2021-12-02_17-29.h5
# [PosixPath('/mnt/Data/data/output/evaluator/threshold_recordings_subset_50th_12_15uV_20000Hz_2021-12-02_19-01.h5'), PosixPath('/mnt/Data/data/output/evaluator/threshold_normalized_subset_50th_12_15uV_20000Hz_2021-12-02_19-01.h5'), PosixPath('/mnt/Data/data/output/evaluator/threshold_neo_subset_50th_12_15uV_20000Hz_2021-12-02_19-01.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Data/data/output/preprocessor/preprocessed_neo_12_25uV_20000Hz_2021-12-02_17-29.h5
# [PosixPath('/mnt/Data/data/output/evaluator/threshold_recordings_subset_50th_12_25uV_20000Hz_2021-12-02_19-02.h5'), PosixPath('/mnt/Data/data/output/evaluator/threshold_normalized_subset_50th_12_25uV_20000Hz_2021-12-02_19-02.h5'), PosixPath('/mnt/Data/data/output/evaluator/threshold_neo_subset_50th_12_25uV_20000Hz_2021-12-02_19-02.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Data/data/output/preprocessor/preprocessed_neo_10_5uV_20000Hz_2021
data/output-bw-300-1000/evaluator/threshold_neo_subset_50th_6_25uV_20000Hz_2021-12-02_23-50.h5')]

# %% [markdown]
# ## Getting indexes for spiketrains positions

# %%
spiketrain_obj_list = neo_list[0][0][0]["recordings"].spiketrains

# %%
import numpy as np

# %%
spiketrain_list = [np.array(spiketrain[:]) for spiketrain in spiketrain_obj_list]

# %%
timestamps = neo_list[0][0][0]["recordings"].timestamps[:]
print(timestamps)
# Out:
# [0.00000e+00 5.00000e-05 1.00000e-04 ... 9.99985e+00 9.99990e+00
#  9.99995e+00]

# %%
from eapprocessor.evaluator.spikes import estimate_sample_spikes, comparison_detection_spiketrain

# %%
indexes_list = []
errors_list = []
for spiketrain in spiketrain_list:
    indexes, errors = estimate_sample_spikes(spikes=spiketrain,timestamps=timestamps)
    indexes_list += [indexes]
    errors_list += [errors]

# %% [markdown]
# ## Evaluating for each noise level

# %%
from eapprocessor.process import get_results_evaluation_dataset_array
from eapprocessor.evaluator.spikes import convert_to_roc_list
from eapprocessor.plot.evaluator import plot_roc_list, plot_accuracy_list

# %%
def results_evaluator(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      noise_levels,
                      w):
    evaluator_files_neo = [evaluator_files_dict["neo_file"]
                           for evaluator_files_dict in evaluator_files_dict_list]
    neo_evaluation_dics = get_results_evaluation_dataset_array(evaluator_files_neo, 
                                                               indexes_list,
                                                               channel_idx=1)

    tpr_neo_list, fpr_neo_list = convert_to_roc_list(neo_evaluation_dics, 
                                                     range_reference=spike_indexes)

    print(tpr_neo_list.shape)
    
    for idx in range(len(tpr_neo_list)):
        plot_roc_list(fpr_list=fpr_neo_list[idx], tpr_list=tpr_neo_list[idx], 
                    labels=[f"w={w_i}" for w_i in w],
                    spiketrains_labels=spike_indexes,
                    append_title=f", Noise level {noise_levels[idx]}")

# %%
results_evaluator(evaluator_files_dict_list[0][0],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32])
# Out:
# (3, 4, 50, 3)

# %%
results_evaluator(evaluator_files_dict_list[1][0],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32])
# Out:
# (3, 4, 50, 3)

# %%
results_evaluator(evaluator_files_dict_list[2][0],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32])
# Out:
# (3, 4, 50, 3)

# %%
from eapprocessor.evaluator.spikes import comparison_detection_array_spiketrain_array, convert_to_roc, \
    convert_to_accuracy, convert_to_accuracy_list
from eapprocessor.tools.load import load_evaluation

# %%
def results_recordings(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      noise_levels):
    evaluator_files_rec = [load_evaluation(evaluator_files_dict["recordings_file"])
                           for evaluator_files_dict in evaluator_files_dict_list]
    
    comparison_recordings_list = [comparison_detection_array_spiketrain_array(indexes_list, dic["indexes"][1]) 
                             for dic in evaluator_files_rec]

    tpr_rec_list = []
    fpr_rec_list = []
    for comparison_rec in comparison_recordings_list:
        tpr_rec, fpr_rec = convert_to_roc(comparison_rec, range_reference=spike_indexes)
        tpr_rec_list +=[tpr_rec]
        fpr_rec_list +=[fpr_rec]
    
    plot_roc_list(fpr_list=fpr_rec_list, tpr_list=tpr_rec_list, 
                labels=[f"noise={noise_level}" for noise_level in noise_levels],
                spiketrains_labels=spike_indexes)

# %%
results_recordings(evaluator_files_dict_list[0][0],
                 indexes_list,
                 [5,7,8],
                 noise_levels)

# %%
def results_converted(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      noise_levels):
    evaluator_files_rec = [load_evaluation(evaluator_files_dict["normalized_file"])
                           for evaluator_files_dict in evaluator_files_dict_list]
    
    comparison_recordings_list = [comparison_detection_array_spiketrain_array(indexes_list, dic["indexes"][1]) 
                             for dic in evaluator_files_rec]

    tpr_rec_list = []
    fpr_rec_list = []
    for comparison_rec in comparison_recordings_list:
        tpr_rec, fpr_rec = convert_to_roc(comparison_rec, range_reference=spike_indexes)
        tpr_rec_list +=[tpr_rec]
        fpr_rec_list +=[fpr_rec]
    
    plot_roc_list(fpr_list=fpr_rec_list, tpr_list=tpr_rec_list, 
                labels=[f"noise={noise_level}" for noise_level in noise_levels],
                spiketrains_labels=spike_indexes)

# %%
results_converted(evaluator_files_dict_list[0][4],
                 indexes_list,
                 [5,7,8],
                 noise_levels)

# %%
def results_accuracy_converted(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      labels):
    evaluator_files_rec = [load_evaluation(evaluator_files_dict["normalized_file"])
                           for evaluator_files_dict in evaluator_files_dict_list]
    
    comparison_recordings_list = [comparison_detection_array_spiketrain_array(indexes_list, dic["indexes"][1],50) 
                             for dic in evaluator_files_rec]

    accuracy_list = convert_to_accuracy_list(comparison_recordings_list, range_reference=spike_indexes)

    
    plot_accuracy_list(accuracy_list=accuracy_list, 
                labels=labels,
                spiketrains_labels=spike_indexes)
    return accuracy_list

# %%
results_accuracy_converted(evaluator_files_dict_list[0][0],
                 indexes_list,
                 [5,7,8],
                 [f"noise={noise_level}" for noise_level in noise_levels])
# Out:
# array([[[0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01454728, 0.02728411, 0.03505258],
#         [0.01632883, 0.03080837, 0.03952569],
#         [0.02751423, 0.05227818, 0.06660324],
#         [0.04886268, 0.09284497, 0.11570248],
#         [0.07426376, 0.13956466, 0.175     ],
#         [0.09220986, 0.1738437 , 0.2247191 ],
#         [0.10701107, 0.19890511, 0.27079304],
#         [0.11553785, 0.21584158, 0.30905077],
#         [0.12366738, 0.2289916 , 0.3286385 ],
#         [0.1277533 , 0.23695652, 0.3406326 ],
#         [0.13033708, 0.24276169, 0.34482759],
#         [0.13583138, 0.24597701, 0.35175879],
#         [0.13701923, 0.25178147, 0.35989717],
#         [0.14030612, 0.25757576, 0.37940379],
#         [0.13858696, 0.2393617 , 0.40406977],
#         [0.13622291, 0.20289855, 0.46333333],
#         [0.09677419, 0.16171617, 0.58158996],
#         [0.07053942, 0.09677419, 0.71649485],
#         [0.04090909, 0.06130268, 0.8373494 ],
#         [0.01877934, 0.04743083, 0.89677419],
#         [0.01470588, 0.03265306, 0.95862069],
#         [0.015     , 0.0204918 , 0.97183099],
#         [0.01515152, 0.01646091, 0.97163121],
#         [0.01530612, 0.01659751, 0.95744681],
#         [0.01538462, 0.01244813, 0.96428571],
#         [0.01578947, 0.01271186, 0.92857143],
#         [0.01694915, 0.01339286, 0.84285714],
#         [0.01886792, 0.01442308, 0.72857143],
#         [0.02068966, 0.01025641, 0.62857143],
#         [0.0234375 , 0.01117318, 0.51428571],
#         [0.02752294, 0.0125    , 0.37857143],
#         [0.03191489, 0.00684932, 0.27142857],
#         [0.0375    , 0.00757576, 0.17142857],
#         [0.02816901, 0.00819672, 0.1       ],
#         [0.02985075, 0.00847458, 0.07142857],
#         [0.03125   , 0.00869565, 0.05      ],
#         [0.03278689, 0.00892857, 0.02857143],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.03389831, 0.00900901, 0.02142857],
#         [0.01694915, 0.00909091, 0.01428571],
#         [0.01694915, 0.00909091, 0.01428571],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286]],
#
#        [[0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01452542, 0.02726363, 0.0350438 ],
#         [0.0145327 , 0.02727045, 0.0350438 ],
#         [0.01457286, 0.02735257, 0.03509652],
#         [0.01473952, 0.02758795, 0.03543407],
#         [0.01508845, 0.02824566, 0.03620378],
#         [0.01570964, 0.02893456, 0.03777658],
#         [0.0167727 , 0.03003176, 0.04070951],
#         [0.01861958, 0.03285486, 0.04494382],
#         [0.02137855, 0.03589744, 0.05143277],
#         [0.02504318, 0.03967577, 0.06013746],
#         [0.02900844, 0.041841  , 0.07354497],
#         [0.03491436, 0.04941482, 0.09084881],
#         [0.03694779, 0.0585405 , 0.11202636],
#         [0.04339051, 0.06306306, 0.13924051],
#         [0.04915912, 0.07061791, 0.17479675],
#         [0.04901961, 0.06875   , 0.2137931 ],
#         [0.05749487, 0.07101727, 0.25431034],
#         [0.06020942, 0.0760095 , 0.30769231],
#         [0.06666667, 0.06371191, 0.35197368],
#         [0.06177606, 0.05863192, 0.38976378],
#         [0.07009346, 0.05639098, 0.42592593],
#         [0.04945055, 0.05194805, 0.43386243],
#         [0.05555556, 0.05714286, 0.4180791 ],
#         [0.0472973 , 0.05102041, 0.39053254],
#         [0.03816794, 0.04469274, 0.32515337],
#         [0.02586207, 0.04938272, 0.2987013 ],
#         [0.02777778, 0.03846154, 0.27152318],
#         [0.03157895, 0.02777778, 0.23448276],
#         [0.02298851, 0.02205882, 0.18881119],
#         [0.02564103, 0.02362205, 0.12587413],
#         [0.02777778, 0.02479339, 0.0915493 ],
#         [0.02816901, 0.025     , 0.08450704],
#         [0.02941176, 0.01694915, 0.07092199],
#         [0.03076923, 0.00854701, 0.06428571],
#         [0.03174603, 0.00869565, 0.05      ],
#         [0.03278689, 0.        , 0.03571429],
#         [0.03448276, 0.        , 0.01428571],
#         [0.03448276, 0.        , 0.01428571]],
#
#        [[0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03503504],
#         [0.01452542, 0.02726363, 0.03506136],
#         [0.0145327 , 0.02728411, 0.03507014],
#         [0.01456554, 0.02733885, 0.03511412],
#         [0.01464646, 0.02748361, 0.03528226],
#         [0.01485275, 0.02729592, 0.03576903],
#         [0.0151912 , 0.02712572, 0.03623566],
#         [0.01573095, 0.02730468, 0.03728722],
#         [0.01623007, 0.02751773, 0.0393611 ],
#         [0.01718846, 0.02838828, 0.04156404],
#         [0.01716016, 0.029     , 0.04327407],
#         [0.01845574, 0.02919162, 0.04670433],
#         [0.01869565, 0.02955032, 0.05034423],
#         [0.02064451, 0.03101551, 0.05444555],
#         [0.02210275, 0.03239105, 0.05809859],
#         [0.02527076, 0.03528582, 0.06718529],
#         [0.02599653, 0.03637902, 0.07337884],
#         [0.02620545, 0.03917526, 0.07897436],
#         [0.02752294, 0.04358974, 0.07964602],
#         [0.02711864, 0.0384    , 0.07716535],
#         [0.02959831, 0.04109589, 0.07428571],
#         [0.02307692, 0.04449649, 0.0744921 ],
#         [0.02777778, 0.04545455, 0.08045977],
#         [0.02489627, 0.04964539, 0.06514658],
#         [0.0255102 , 0.05      , 0.05992509],
#         [0.01829268, 0.0430622 , 0.05063291],
#         [0.01626016, 0.02941176, 0.04040404],
#         [0.01923077, 0.01948052, 0.03296703],
#         [0.01111111, 0.02158273, 0.01169591],
#         [0.01298701, 0.01574803, 0.        ],
#         [0.01408451, 0.01652893, 0.        ],
#         [0.01449275, 0.01680672, 0.        ],
#         [0.        , 0.00869565, 0.        ],
#         [0.        , 0.00884956, 0.        ],
#         [0.        , 0.        , 0.        ]]])

# %%
results_accuracy_converted(evaluator_files_dict_list[0][4],
                 indexes_list,
                 [5,7,8],
                 [f"noise={noise_level}" for noise_level in noise_levels])
# Out:
# array([[[0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01757043, 0.03318113, 0.04225777],
#         [0.01757043, 0.03318113, 0.04225777],
#         [0.05065502, 0.09628975, 0.12173913],
#         [0.05065502, 0.09628975, 0.12173913],
#         [0.09570957, 0.18106312, 0.24305556],
#         [0.11958763, 0.2193159 , 0.31818182],
#         [0.11958763, 0.2193159 , 0.31818182],
#         [0.12719298, 0.23747277, 0.33816425],
#         [0.12719298, 0.23747277, 0.33816425],
#         [0.13647059, 0.25115207, 0.34739454],
#         [0.13647059, 0.25115207, 0.34739454],
#         [0.1425    , 0.26433915, 0.36363636],
#         [0.1425    , 0.26433915, 0.36363636],
#         [0.15384615, 0.27323944, 0.41492537],
#         [0.12585034, 0.21474359, 0.52651515],
#         [0.12585034, 0.21474359, 0.52651515],
#         [0.06113537, 0.09363296, 0.7679558 ],
#         [0.06113537, 0.09363296, 0.7679558 ],
#         [0.01904762, 0.048     , 0.91447368],
#         [0.01904762, 0.048     , 0.91447368],
#         [0.015     , 0.0204918 , 0.97183099],
#         [0.01530612, 0.01659751, 0.95744681],
#         [0.01530612, 0.01659751, 0.95744681],
#         [0.01554404, 0.0125    , 0.95714286],
#         [0.01554404, 0.0125    , 0.95714286],
#         [0.01744186, 0.01351351, 0.82857143],
#         [0.01744186, 0.01351351, 0.82857143],
#         [0.02142857, 0.0104712 , 0.6       ],
#         [0.02142857, 0.0104712 , 0.6       ],
#         [0.02777778, 0.01257862, 0.37142857],
#         [0.03703704, 0.0075188 , 0.17857143],
#         [0.03703704, 0.0075188 , 0.17857143],
#         [0.02898551, 0.00833333, 0.08571429],
#         [0.02898551, 0.00833333, 0.08571429],
#         [0.03278689, 0.00892857, 0.02857143],
#         [0.03278689, 0.00892857, 0.02857143],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.03333333, 0.00900901, 0.02142857],
#         [0.01694915, 0.00909091, 0.01428571],
#         [0.01694915, 0.00909091, 0.01428571],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286],
#         [0.01724138, 0.        , 0.00714286]],
#
#        [[0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01452178, 0.02726363, 0.0350438 ],
#         [0.01452178, 0.02726363, 0.0350438 ],
#         [0.0145692 , 0.02736631, 0.03517588],
#         [0.0145692 , 0.02736631, 0.03517588],
#         [0.01497934, 0.02802057, 0.03599897],
#         [0.01616499, 0.02973048, 0.0390625 ],
#         [0.01616499, 0.02973048, 0.0390625 ],
#         [0.01908523, 0.03331156, 0.04590164],
#         [0.01908523, 0.03331156, 0.04590164],
#         [0.02418682, 0.03986711, 0.05818786],
#         [0.03139535, 0.04561201, 0.08201523],
#         [0.03139535, 0.04561201, 0.08201523],
#         [0.04124579, 0.06265664, 0.11561691],
#         [0.04124579, 0.06265664, 0.11561691],
#         [0.05115713, 0.06777646, 0.16267339],
#         [0.05204461, 0.07269504, 0.24212598],
#         [0.05204461, 0.07269504, 0.24212598],
#         [0.06504065, 0.07542579, 0.32763533],
#         [0.06504065, 0.07542579, 0.32763533],
#         [0.06934307, 0.0621118 , 0.38867925],
#         [0.06763285, 0.05019305, 0.42654028],
#         [0.06763285, 0.05019305, 0.42654028],
#         [0.05521472, 0.05188679, 0.43181818],
#         [0.05521472, 0.05188679, 0.43181818],
#         [0.05109489, 0.05376344, 0.37195122],
#         [0.02564103, 0.04938272, 0.32236842],
#         [0.02564103, 0.04938272, 0.32236842],
#         [0.02912621, 0.04      , 0.25503356],
#         [0.02912621, 0.04      , 0.25503356],
#         [0.02409639, 0.02272727, 0.16901408],
#         [0.02702703, 0.02439024, 0.1056338 ],
#         [0.02702703, 0.02439024, 0.1056338 ],
#         [0.02816901, 0.025     , 0.08450704],
#         [0.02816901, 0.025     , 0.08450704],
#         [0.03076923, 0.00854701, 0.06428571],
#         [0.03225806, 0.        , 0.04285714],
#         [0.03225806, 0.        , 0.04285714],
#         [0.03448276, 0.        , 0.01428571]],
#
#        [[0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03501751],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03502627],
#         [0.01451815, 0.02725681, 0.03503504],
#         [0.01452178, 0.02726363, 0.03505258],
#         [0.01453634, 0.02727728, 0.03506136],
#         [0.01455823, 0.02734571, 0.03511412],
#         [0.01468354, 0.02753221, 0.03535354],
#         [0.0149177 , 0.02757916, 0.03585147],
#         [0.01527924, 0.02758077, 0.0362395 ],
#         [0.01591221, 0.02759563, 0.03786008],
#         [0.01669596, 0.02827164, 0.0401524 ],
#         [0.01772478, 0.02805228, 0.04247104],
#         [0.01772478, 0.02805228, 0.04247104],
#         [0.01724757, 0.02954788, 0.04519369],
#         [0.01876564, 0.02924217, 0.04960728],
#         [0.02012458, 0.03136882, 0.05290753],
#         [0.0232423 , 0.03344867, 0.05733945],
#         [0.0256593 , 0.03573931, 0.06605762],
#         [0.02620087, 0.03757472, 0.07632933],
#         [0.02906351, 0.03797468, 0.07651992],
#         [0.02724796, 0.03664921, 0.08366013],
#         [0.03014184, 0.04145937, 0.08388158],
#         [0.02714932, 0.041841  , 0.0862423 ],
#         [0.02346041, 0.04188482, 0.07518797],
#         [0.03053435, 0.04560261, 0.0733945 ],
#         [0.03053435, 0.04560261, 0.0733945 ],
#         [0.02870813, 0.0513834 , 0.0569395 ],
#         [0.0297619 , 0.04205607, 0.05833333],
#         [0.01550388, 0.03428571, 0.03921569],
#         [0.00943396, 0.02597403, 0.02717391],
#         [0.01086957, 0.0212766 , 0.02339181],
#         [0.01298701, 0.01574803, 0.00628931],
#         [0.01408451, 0.01652893, 0.        ],
#         [0.01470588, 0.01694915, 0.        ],
#         [0.        , 0.00877193, 0.        ],
#         [0.        , 0.00900901, 0.        ],
#         [0.        , 0.        , 0.        ]]])

# %%
evaluator_files_5uv_12bits_list= [evaluator_files[0][0] for evaluator_files in  evaluator_files_dict_list]
evaluator_files_25uv_12bits_list= [evaluator_files[0][2] for evaluator_files in  evaluator_files_dict_list]

# %%
bws=["0.3-6k","0.3-3k","0.3-1k"]

# %%
results_5uv_12bits = results_accuracy_converted(evaluator_files_5uv_12bits_list,
                 indexes_list,
                 [5,7,8],
                 [f"bw={bw}" for bw in bws])

# %%
results_25uv_12bits = results_accuracy_converted(evaluator_files_25uv_12bits_list,
                 indexes_list,
                 [5,7,8],
                 [f"bw={bw}" for bw in bws])

# %%
results_5uv_12bits.shape
results_5uv_12bits_t = np.transpose(results_5uv_12bits, (2, 0, 1))
results_5uv_12bits_t.shape
# Out:
# (3, 3, 50)

# %%
results_25uv_12bits_t = np.transpose(results_25uv_12bits, (2, 0, 1))
results_25uv_12bits_t.shape
# Out:
# (3, 3, 50)

# %%
import matplotlib.pyplot as plt

# %%
upper_limit=[6,3,1]

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
for idx,spiketrain in enumerate([5,7,8]):
    vector = results_5uv_12bits_t[idx].max(axis=1)
    ax.plot(upper_limit,vector,label=f"Spiketrain {spiketrain}")
    ax.set_xlabel("BW Upper Limit (kHz)")
    ax.set_ylabel("Accuracy")
    ax.legend(loc="best")
    ax.set_title("Variation with resolution, 5uV noise")
    ax.grid(True)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
for idx,spiketrain in enumerate([5,7,8]):
    vector = results_25uv_12bits_t[idx].max(axis=1)
    ax.plot(upper_limit,vector,label=f"Spiketrain {spiketrain}")
    ax.set_xlabel("BW Upper Limit (kHz)")
    ax.set_ylabel("Accuracy")
    ax.legend(loc="best")
    ax.set_title("Variation with resolution, 25uV noise")
    ax.grid(True)

# %%
from eapprocessor.plot import save_figure, set_tex_enabled

# %%
set_tex_enabled(True)

# %%
fig = plt.figure(figsize=(10,4))
axes = fig.subplots(ncols=2, nrows=1)
results = [results_5uv_12bits_t, results_25uv_12bits_t]

for ax, result, noise_level in zip(axes.ravel(), results, [noise_levels[0],noise_levels[2]]):
    for idx,spiketrain in enumerate([5,7,8]):
        vector = result[idx].max(axis=1)
        ax.plot(upper_limit,vector,label=f"Spiketrain {spiketrain}")
        ax.set_xlabel("BW Upper Limit (kHz)")
        ax.set_ylabel("Accuracy")
        ax.legend(loc="best")
        ax.set_title(f"Variation with resolution, {noise_level}uV noise")
        ax.grid(True)

# %%
from pathlib import Path

# %%
FIGURE_FOLDER = "/mnt/Archivos/Nextcloud/MaestriaPUCP/Thesis/thesis/images"
figure_path = Path(FIGURE_FOLDER)

# %%
save_figure(fig, figure_path / "evaluation_bandwidth.pdf")
