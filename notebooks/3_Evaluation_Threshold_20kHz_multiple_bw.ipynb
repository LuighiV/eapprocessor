# %% [markdown]
# # Threshold Evaluation for multiple bw values
#
# This stage evaluates the results with the detector, comparing them with the original spiketrains. To do this, it requires to load the NEO files for each value of resolution.

# %% [markdown]
# ## Loading NEO files

# %%
# %load_ext autoreload
# %autoreload 2

# %%
BASE_DIR="/mnt/Archivos/data"

# %%
from eapprocessor.tools.load import load_neo, load_count_evaluation, get_evaluation_files

# %%
noise_levels = [5, 25, 50]
resolutions = [12,10,9,8,7,6]
neofolders = [
    f"{BASE_DIR}/output/preprocessor",
    f"{BASE_DIR}/output-bw-300-3000/preprocessor",
    f"{BASE_DIR}/output-bw-300-1000/preprocessor"
]
fs=20000

# %%
neo_list=[]
neo_files=[]
for neofolder in neofolders:
    neo_list_bw = []
    neo_files_bw = []
    for resolution in resolutions:
        neo_list_resolution = []
        neo_files_resolution =[]
        for noise_level in noise_levels:
            neo_dict, file = load_neo(neofolder, verbose=True, resolution=resolution, 
                               noise_level=noise_level, fs=fs)
            neo_list_resolution += [neo_dict]
            neo_files_resolution += [file]

        neo_list_bw += [neo_list_resolution]
        neo_files_bw += [neo_files_resolution]
    neo_list += [neo_list_bw]
    neo_files += [neo_files_bw]
# Out:
# Search for pattern: *_12_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_12_5uV_20000Hz_2021-10-04_12-19.h5
# Search for pattern: *_12_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_12_25uV_20000Hz_2021-10-04_12-20.h5
# Search for pattern: *_12_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_12_50uV_20000Hz_2021-10-04_12-20.h5
# Search for pattern: *_10_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_10_5uV_20000Hz_2021-11-04_16-18.h5
# Search for pattern: *_10_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_10_25uV_20000Hz_2021-11-04_16-18.h5
# Search for pattern: *_10_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_10_50uV_20000Hz_2021-11-04_16-18.h5
# Search for pattern: *_9_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_9_5uV_20000Hz_2021-11-04_16-18.h5
# Search for pattern: *_9_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_9_25uV_20000Hz_2021-11-04_16-18.h5
# Search for pattern: *_9_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_9_50uV_20000Hz_2021-11-04_16-19.h5
# Search for pattern: *_8_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_8_5uV_20000Hz_2021-11-04_16-19.h5
# Search for pattern: *_8_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_8_25uV_20000Hz_2021-11-04_16-19.h5
# Search for pattern: *_8_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_8_50uV_20000Hz_2021-11-04_16-19.h5
# Search for pattern: *_7_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_7_5uV_20000Hz_2021-11-04_16-19.h5
# Search for pattern: *_7_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_7_25uV_20000Hz_2021-11-04_16-20.h5
# Search for pattern: *_7_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_7_50uV_20000Hz_2021-11-04_16-20.h5
# Search for pattern: *_6_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_6_5uV_20000Hz_2021-11-04_16-20.h5
# Search for pattern: *_6_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_6_25uV_20000Hz_2021-11-04_16-20.h5
# Search for pattern: *_6_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output/preprocessor/preprocessed_neo_6_50uV_20000Hz_2021-11-04_16-20.h5
# Search for pattern: *_12_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_12_5uV_20000Hz_2021-11-09_19-49.h5
# Search for pattern: *_12_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_12_25uV_20000Hz_2021-11-09_19-49.h5
# Search for pattern: *_12_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_12_50uV_20000Hz_2021-11-09_19-49.h5
# Search for pattern: *_10_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_10_5uV_20000Hz_2021-11-09_19-50.h5
# Search for pattern: *_10_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_10_25uV_20000Hz_2021-11-09_19-50.h5
# Search for pattern: *_10_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_10_50uV_20000Hz_2021-11-09_19-50.h5
# Search for pattern: *_9_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_9_5uV_20000Hz_2021-11-09_19-50.h5
# Search for pattern: *_9_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_9_25uV_20000Hz_2021-11-09_19-51.h5
# Search for pattern: *_9_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_9_50uV_20000Hz_2021-11-09_19-51.h5
# Search for pattern: *_8_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_8_5uV_20000Hz_2021-11-09_19-51.h5
# Search for pattern: *_8_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_8_25uV_20000Hz_2021-11-09_19-51.h5
# Search for pattern: *_8_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_8_50uV_20000Hz_2021-11-09_19-51.h5
# Search for pattern: *_7_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_7_5uV_20000Hz_2021-11-09_19-52.h5
# Search for pattern: *_7_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_7_25uV_20000Hz_2021-11-09_19-52.h5
# Search for pattern: *_7_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_7_50uV_20000Hz_2021-11-09_19-52.h5
# Search for pattern: *_6_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_6_5uV_20000Hz_2021-11-09_19-53.h5
# Search for pattern: *_6_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_6_25uV_20000Hz_2021-11-09_19-53.h5
# Search for pattern: *_6_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-3000/preprocessor/preprocessed_neo_6_50uV_20000Hz_2021-11-09_19-53.h5
# Search for pattern: *_12_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_12_5uV_20000Hz_2021-11-09_19-53.h5
# Search for pattern: *_12_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_12_25uV_20000Hz_2021-11-09_19-53.h5
# Search for pattern: *_12_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_12_50uV_20000Hz_2021-11-09_19-53.h5
# Search for pattern: *_10_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_10_5uV_20000Hz_2021-11-09_19-54.h5
# Search for pattern: *_10_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_10_25uV_20000Hz_2021-11-09_19-54.h5
# Search for pattern: *_10_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_10_50uV_20000Hz_2021-11-09_19-54.h5
# Search for pattern: *_9_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_9_5uV_20000Hz_2021-11-09_19-55.h5
# Search for pattern: *_9_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_9_25uV_20000Hz_2021-11-09_19-55.h5
# Search for pattern: *_9_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_9_50uV_20000Hz_2021-11-09_19-55.h5
# Search for pattern: *_8_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_8_5uV_20000Hz_2021-11-09_19-55.h5
# Search for pattern: *_8_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_8_25uV_20000Hz_2021-11-09_19-55.h5
# Search for pattern: *_8_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_8_50uV_20000Hz_2021-11-09_19-56.h5
# Search for pattern: *_7_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_7_5uV_20000Hz_2021-11-09_19-56.h5
# Search for pattern: *_7_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_7_25uV_20000Hz_2021-11-09_19-56.h5
# Search for pattern: *_7_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_7_50uV_20000Hz_2021-11-09_19-56.h5
# Search for pattern: *_6_5uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_6_5uV_20000Hz_2021-11-09_19-57.h5
# Search for pattern: *_6_25uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_6_25uV_20000Hz_2021-11-09_19-57.h5
# Search for pattern: *_6_50uV_20000Hz*
# Loading file /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_6_50uV_20000Hz_2021-11-09_19-57.h5

# %% [markdown]
# ## Exploring converted signals

# %%
from eapprocessor.plot.signals import plot_transient_converted, plot_transient_recordings, plot_transient_neo

# %%
plot_transient_recordings(neo_list[0][0]["recordings"], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_converted(neo_list[0][0], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_converted(neo_list[4][0], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_neo(neo_list[0][0], channels=[27], t_stop=0.1,marker='.--')

# %%
plot_transient_neo(neo_list[4][0], channels=[27], t_stop=0.1,marker='.--')

# %% [markdown]
# ## Getting evaluation files

# %%
evalfolders = [
    f"{BASE_DIR}/output/evaluator",
    f"{BASE_DIR}/output-bw-300-3000/evaluator",
    f"{BASE_DIR}/output-bw-300-1000/evaluator"
]

# %%
evaluator_files_dict_list = []
for idx, neo_files_bw in enumerate(neo_files):
    evaluator_files_dict_bw =[]
    for neo_files_resolution in neo_files_bw:
        evaluator_files_dict_list_resolution=[]
        for neo_file in neo_files_resolution: 
            file_dict = get_evaluation_files(evalfolders[idx],sourcefile=neo_file) 
            evaluator_files_dict_list_resolution += [file_dict]
        evaluator_files_dict_bw += [evaluator_files_dict_list_resolution]
    evaluator_files_dict_list+= [evaluator_files_dict_bw]
# Out:
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output/preprocessor/preprocessed_neo_12_5uV_20000Hz_2021-10-04_12-19.h5
# [PosixPath('/mnt/Archivos/data/output/evaluator/threshold_recordings_subset_50th_12_5uV_20000Hz_2021-10-14_23-46.h5'), PosixPath('/mnt/Archivos/data/output/evaluator/threshold_normalized_subset_50th
h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_8_25uV_20000Hz_2021-11-09_19-55.h5
# [PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_recordings_subset_50th_8_25uV_20000Hz_2021-11-11_12-54.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_normalized_subset_50th_8_25uV_20000Hz_2021-11-11_12-54.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_neo_subset_50th_8_25uV_20000Hz_2021-11-11_12-54.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_8_50uV_20000Hz_2021-11-09_19-56.h5
# [PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_recordings_subset_50th_8_50uV_20000Hz_2021-11-11_12-55.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_normalized_subset_50th_8_50uV_20000Hz_2021-11-11_12-55.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_neo_subset_50th_8_50uV_20000Hz_2021-11-11_12-55.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_7_5uV_20000Hz_2021-11-09_19-56.h5
# [PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_recordings_subset_50th_7_5uV_20000Hz_2021-11-11_12-56.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_normalized_subset_50th_7_5uV_20000Hz_2021-11-11_12-56.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_neo_subset_50th_7_5uV_20000Hz_2021-11-11_12-56.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_7_25uV_20000Hz_2021-11-09_19-56.h5
# [PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_recordings_subset_50th_7_25uV_20000Hz_2021-11-11_12-56.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_normalized_subset_50th_7_25uV_20000Hz_2021-11-11_12-56.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_neo_subset_50th_7_25uV_20000Hz_2021-11-11_12-56.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_7_50uV_20000Hz_2021-11-09_19-56.h5
# [PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_recordings_subset_50th_7_50uV_20000Hz_2021-11-11_12-57.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_normalized_subset_50th_7_50uV_20000Hz_2021-11-11_12-57.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_neo_subset_50th_7_50uV_20000Hz_2021-11-11_12-57.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_6_5uV_20000Hz_2021-11-09_19-57.h5
# [PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_recordings_subset_50th_6_5uV_20000Hz_2021-11-11_12-58.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_normalized_subset_50th_6_5uV_20000Hz_2021-11-11_12-58.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_neo_subset_50th_6_5uV_20000Hz_2021-11-11_12-58.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_6_25uV_20000Hz_2021-11-09_19-57.h5
# [PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_recordings_subset_50th_6_25uV_20000Hz_2021-11-11_12-58.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_normalized_subset_50th_6_25uV_20000Hz_2021-11-11_12-58.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_neo_subset_50th_6_25uV_20000Hz_2021-11-11_12-59.h5')]
# Search for pattern: *
# Filename found 3 files with source /mnt/Archivos/data/output-bw-300-1000/preprocessor/preprocessed_neo_6_50uV_20000Hz_2021-11-09_19-57.h5
# [PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_recordings_subset_50th_6_50uV_20000Hz_2021-11-11_12-59.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_normalized_subset_50th_6_50uV_20000Hz_2021-11-11_12-59.h5'), PosixPath('/mnt/Archivos/data/output-bw-300-1000/evaluator/threshold_neo_subset_50th_6_50uV_20000Hz_2021-11-11_12-59.h5')]

# %% [markdown]
# ## Getting indexes for spiketrains positions

# %%
spiketrain_obj_list = neo_list[0][0][0]["recordings"].spiketrains

# %%
import numpy as np

# %%
spiketrain_list = [np.array(spiketrain[:]) for spiketrain in spiketrain_obj_list]

# %%
timestamps = neo_list[0][0][0]["recordings"].timestamps[:]
print(timestamps)
# Out:
# [0.00000e+00 5.00000e-05 1.00000e-04 ... 9.99985e+00 9.99990e+00
#  9.99995e+00]

# %%
from eapprocessor.evaluator.spikes import estimate_sample_spikes, comparison_detection_spiketrain

# %%
indexes_list = []
errors_list = []
for spiketrain in spiketrain_list:
    indexes, errors = estimate_sample_spikes(spikes=spiketrain,timestamps=timestamps)
    indexes_list += [indexes]
    errors_list += [errors]

# %% [markdown]
# ## Evaluating for each noise level

# %%
from eapprocessor.process import get_results_evaluation_dataset_array
from eapprocessor.evaluator.spikes import convert_to_roc_list
from eapprocessor.plot.evaluator import plot_roc_list, plot_accuracy_list

# %%
def results_evaluator(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      noise_levels,
                      w):
    evaluator_files_neo = [evaluator_files_dict["neo_file"]
                           for evaluator_files_dict in evaluator_files_dict_list]
    neo_evaluation_dics = get_results_evaluation_dataset_array(evaluator_files_neo, 
                                                               indexes_list,
                                                               channel_idx=1)

    tpr_neo_list, fpr_neo_list = convert_to_roc_list(neo_evaluation_dics, 
                                                     range_reference=spike_indexes)

    print(tpr_neo_list.shape)
    
    for idx in range(len(tpr_neo_list)):
        plot_roc_list(fpr_list=fpr_neo_list[idx], tpr_list=tpr_neo_list[idx], 
                    labels=[f"w={w_i}" for w_i in w],
                    spiketrains_labels=spike_indexes,
                    append_title=f", Noise level {noise_levels[idx]}")

# %%
results_evaluator(evaluator_files_dict_list[0][0],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32])
# Out:
# (3, 4, 50, 3)

# %%
results_evaluator(evaluator_files_dict_list[1][0],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32])
# Out:
# (3, 4, 50, 3)

# %%
results_evaluator(evaluator_files_dict_list[2][0],
                 indexes_list,
                 [5,7,8],
                 noise_levels,
                 [1,4,16,32])
# Out:
# (3, 4, 50, 3)

# %%
from eapprocessor.evaluator.spikes import comparison_detection_array_spiketrain_array, convert_to_roc, \
    convert_to_accuracy, convert_to_accuracy_list
from eapprocessor.tools.load import load_evaluation

# %%
def results_recordings(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      noise_levels):
    evaluator_files_rec = [load_evaluation(evaluator_files_dict["recordings_file"])
                           for evaluator_files_dict in evaluator_files_dict_list]
    
    comparison_recordings_list = [comparison_detection_array_spiketrain_array(indexes_list, dic["indexes"][1]) 
                             for dic in evaluator_files_rec]

    tpr_rec_list = []
    fpr_rec_list = []
    for comparison_rec in comparison_recordings_list:
        tpr_rec, fpr_rec = convert_to_roc(comparison_rec, range_reference=spike_indexes)
        tpr_rec_list +=[tpr_rec]
        fpr_rec_list +=[fpr_rec]
    
    plot_roc_list(fpr_list=fpr_rec_list, tpr_list=tpr_rec_list, 
                labels=[f"noise={noise_level}" for noise_level in noise_levels],
                spiketrains_labels=spike_indexes)

# %%
results_recordings(evaluator_files_dict_list[0][0],
                 indexes_list,
                 [5,7,8],
                 noise_levels)

# %%
def results_converted(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      noise_levels):
    evaluator_files_rec = [load_evaluation(evaluator_files_dict["normalized_file"])
                           for evaluator_files_dict in evaluator_files_dict_list]
    
    comparison_recordings_list = [comparison_detection_array_spiketrain_array(indexes_list, dic["indexes"][1]) 
                             for dic in evaluator_files_rec]

    tpr_rec_list = []
    fpr_rec_list = []
    for comparison_rec in comparison_recordings_list:
        tpr_rec, fpr_rec = convert_to_roc(comparison_rec, range_reference=spike_indexes)
        tpr_rec_list +=[tpr_rec]
        fpr_rec_list +=[fpr_rec]
    
    plot_roc_list(fpr_list=fpr_rec_list, tpr_list=tpr_rec_list, 
                labels=[f"noise={noise_level}" for noise_level in noise_levels],
                spiketrains_labels=spike_indexes)

# %%
results_converted(evaluator_files_dict_list[0][4],
                 indexes_list,
                 [5,7,8],
                 noise_levels)

# %%
def results_accuracy_converted(evaluator_files_dict_list,
                      indexes_list,
                      spike_indexes,
                      labels):
    evaluator_files_rec = [load_evaluation(evaluator_files_dict["normalized_file"])
                           for evaluator_files_dict in evaluator_files_dict_list]
    
    comparison_recordings_list = [comparison_detection_array_spiketrain_array(indexes_list, dic["indexes"][1]) 
                             for dic in evaluator_files_rec]

    accuracy_list = convert_to_accuracy_list(comparison_recordings_list, range_reference=spike_indexes)

    
    plot_accuracy_list(accuracy_list=accuracy_list, 
                labels=labels,
                spiketrains_labels=spike_indexes)
    return accuracy_list

# %%
results_accuracy_converted(evaluator_files_dict_list[0][0],
                 indexes_list,
                 [5,7,8],
                 [f"noise={noise_level}" for noise_level in noise_levels])

# %%
results_accuracy_converted(evaluator_files_dict_list[0][4],
                 indexes_list,
                 [5,7,8],
                 [f"noise={noise_level}" for noise_level in noise_levels])

# %%
evaluator_files_5uv_12bits_list= [evaluator_files[0][0] for evaluator_files in  evaluator_files_dict_list]
evaluator_files_25uv_12bits_list= [evaluator_files[0][1] for evaluator_files in  evaluator_files_dict_list]

# %%
bws=["0.3-6k","0.3-3k","0.3-1k"]

# %%
results_5uv_12bits = results_accuracy_converted(evaluator_files_5uv_12bits_list,
                 indexes_list,
                 [5,7,8],
                 [f"bw={bw}" for bw in bws])

# %%
results_25uv_12bits = results_accuracy_converted(evaluator_files_25uv_12bits_list,
                 indexes_list,
                 [5,7,8],
                 [f"bw={bw}" for bw in bws])

# %%
results_5uv_12bits.shape
results_5uv_12bits_t = np.transpose(results_5uv_12bits, (2, 0, 1))
results_5uv_12bits_t.shape
# Out:
# (3, 3, 50)

# %%
results_25uv_12bits_t = np.transpose(results_25uv_12bits, (2, 0, 1))
results_25uv_12bits_t.shape
# Out:
# (3, 3, 50)

# %%
import matplotlib.pyplot as plt

# %%
upper_limit=[6,3,1]

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
for idx,spiketrain in enumerate([5,7,8]):
    vector = results_5uv_12bits_t[idx].max(axis=1)
    ax.plot(upper_limit,vector,label=f"Spiketrain {spiketrain}")
    ax.set_xlabel("BW Upper Limit (kHz)")
    ax.set_ylabel("Accuracy")
    ax.legend(loc="best")
    ax.set_title("Variation with resolution, 5uV noise")
    ax.grid(True)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
for idx,spiketrain in enumerate([5,7,8]):
    vector = results_25uv_12bits_t[idx].max(axis=1)
    ax.plot(upper_limit,vector,label=f"Spiketrain {spiketrain}")
    ax.set_xlabel("BW Upper Limit (kHz)")
    ax.set_ylabel("Accuracy")
    ax.legend(loc="best")
    ax.set_title("Variation with resolution, 25uV noise")
    ax.grid(True)
